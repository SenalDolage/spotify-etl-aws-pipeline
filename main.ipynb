# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import os
from dotenv import load_dotenv
import pandas as pd

# %%
load_dotenv()  # load the .env file
# handle authentication and create a spotipy object
client_credentials_manager = SpotifyClientCredentials(client_id=os.getenv("SPOTIFY_CLIENT_ID"), client_secret=os.getenv("SPOTIFY_CLIENT_SECRET"))
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
# getting the playlist id of most played songs
playlist_link = "https://open.spotify.com/playlist/4yNfFAuHcSgzbcSm6q5QDu"
playlist_id = playlist_link.split("/")[-1]

data = sp.playlist_tracks(playlist_id)
data
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/4yNfFAuHcSgzbcSm6q5QDu/tracks?offset=0&limit=100&additional_types=track',
#  'items': [{'added_at': '2025-04-01T23:38:28Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/qct2gslkz5os8jbwwzj8kebb6'},
#     'href': 'https://api.spotify.com/v1/users/qct2gslkz5os8jbwwzj8kebb6',
#     'id': 'qct2gslkz5os8jbwwzj8kebb6',
#     'type': 'user',
#     'uri': 'spotify:user:qct2gslkz5os8jbwwzj8kebb6'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': None,
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'PR',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'PR',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'type': 'album',
#      'album_type': 'album',
#      'href': 'https://api.spotify.com/v1/albums/1eCGY9WJpYgtaFh1Lk2KNo',
#      'id': '1eCGY9WJpYgtaFh1Lk2KNo',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2731648716c6562145bea491cb6',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e021648716c6562145bea491cb6',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048511648716c6562145bea491cb6',
#        'width': 64}],
#      'name': "You'll Be Alright, Kid (Chapter 1)",
#      'release_date': '2024-09-26',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:1eCGY9WJpYgtaFh1Lk2KNo',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0fTSzq9jAh4c36UVb4V7CB'},
#        'href': 'https://api.spotify.com/v1/artists/0fTSzq9jAh4c36UVb4V7CB',
#        'id': '0fTSzq9jAh4c36UVb4V7CB',
#        'name': 'Alex Warren',
#        'type': 'artist',
#        'uri': 'spotify:artist:0fTSzq9jAh4c36UVb4V7CB'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1eCGY9WJpYgtaFh1Lk2KNo'},
#      'total_tracks': 11},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0fTSzq9jAh4c36UVb4V7CB'},
#       'href': 'https://api.spotify.com/v1/artists/0fTSzq9jAh4c36UVb4V7CB',
#       'id': '0fTSzq9jAh4c36UVb4V7CB',
#       'name': 'Alex Warren',
#       'type': 'artist',
#       'uri': 'spotify:artist:0fTSzq9jAh4c36UVb4V7CB'}],
#     'disc_number': 1,
#     'track_number': 1,
#     'duration_ms': 186964,
#     'external_ids': {'isrc': 'USAT22500463'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2RkZ5LkEzeHGRsmDqKwmaJ'},
#     'href': 'https://api.spotify.com/v1/tracks/2RkZ5LkEzeHGRsmDqKwmaJ',
#     'id': '2RkZ5LkEzeHGRsmDqKwmaJ',
#     'name': 'Ordinary',
#     'popularity': 92,
#     'uri': 'spotify:track:2RkZ5LkEzeHGRsmDqKwmaJ',
#     'is_local': False},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2025-03-11T23:15:56Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/qct2gslkz5os8jbwwzj8kebb6'},
#     'href': 'https://api.spotify.com/v1/users/qct2gslkz5os8jbwwzj8kebb6',
#     'id': 'qct2gslkz5os8jbwwzj8kebb6',
#     'type': 'user',
#     'uri': 'spotify:user:qct2gslkz5os8jbwwzj8kebb6'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': None,
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'type': 'album',
#      'album_type': 'album',
#      'href': 'https://api.spotify.com/v1/albums/2MHUaRi9OCyTN02SoyRRBJ',
#      'id': '2MHUaRi9OCyTN02SoyRRBJ',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273b0860cf0a98e09663c82290c',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02b0860cf0a98e09663c82290c',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851b0860cf0a98e09663c82290c',
#        'width': 64}],
#      'name': 'MAYHEM',
#      'release_date': '2025-03-07',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:2MHUaRi9OCyTN02SoyRRBJ',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#        'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#        'id': '1HY2Jd0NmPuamShAr6KMms',
#        'name': 'Lady Gaga',
#        'type': 'artist',
#        'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2MHUaRi9OCyTN02SoyRRBJ'},
#      'total_tracks': 14},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#       'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#       'id': '1HY2Jd0NmPuamShAr6KMms',
#       'name': 'Lady Gaga',
#       'type': 'artist',
#       'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/0du5cEVh5yTK9QJze8zA0C'},
#       'href': 'https://api.spotify.com/v1/artists/0du5cEVh5yTK9QJze8zA0C',
#       'id': '0du5cEVh5yTK9QJze8zA0C',
#       'name': 'Bruno Mars',
#       'type': 'artist',
#       'uri': 'spotify:artist:0du5cEVh5yTK9QJze8zA0C'}],
#     'disc_number': 1,
#     'track_number': 14,
#     'duration_ms': 251667,
#     'external_ids': {'isrc': 'USUM72409273'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7so0lgd0zP2Sbgs2d7a1SZ'},
#     'href': 'https://api.spotify.com/v1/tracks/7so0lgd0zP2Sbgs2d7a1SZ',
#     'id': '7so0lgd0zP2Sbgs2d7a1SZ',
#     'name': 'Die With A Smile',
#     'popularity': 91,
#     'uri': 'spotify:track:7so0lgd0zP2Sbgs2d7a1SZ',
#     'is_local': False},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2025-01-02T15:25:39Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/qct2gslkz5os8jbwwzj8kebb6'},
#     'href': 'https://api.spotify.com/v1/users/qct2gslkz5os8jbwwzj8kebb6',
#     'id': 'qct2gslkz5os8jbwwzj8kebb6',
#     'type': 'user',
#     'uri': 'spotify:user:qct2gslkz5os8jbwwzj8kebb6'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': None,
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'type': 'album',
#      'album_type': 'album',
#      'href': 'https://api.spotify.com/v1/albums/7aJuG4TFXa2hmE4z1yxc3n',
#      'id': '7aJuG4TFXa2hmE4z1yxc3n',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27371d62ea7ea8a5be92d3c1f62',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0271d62ea7ea8a5be92d3c1f62',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485171d62ea7ea8a5be92d3c1f62',
#        'width': 64}],
#      'name': 'HIT ME HARD AND SOFT',
#      'release_date': '2024-05-17',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:7aJuG4TFXa2hmE4z1yxc3n',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#        'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#        'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#        'name': 'Billie Eilish',
#        'type': 'artist',
#        'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7aJuG4TFXa2hmE4z1yxc3n'},
#      'total_tracks': 10},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#       'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#       'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#       'name': 'Billie Eilish',
#       'type': 'artist',
#       'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#     'disc_number': 1,
#     'track_number': 4,
#     'duration_ms': 210373,
#     'external_ids': {'isrc': 'USUM72401994'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6dOtVTDdiauQNBQEDOtlAB'},
#     'href': 'https://api.spotify.com/v1/tracks/6dOtVTDdiauQNBQEDOtlAB',
#     'id': '6dOtVTDdiauQNBQEDOtlAB',
#     'name': 'BIRDS OF A FEATHER',
#     'popularity': 100,
#     'uri': 'spotify:track:6dOtVTDdiauQNBQEDOtlAB',
#     'is_local': False},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2025-01-02T15:25:39Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/qct2gslkz5os8jbwwzj8kebb6'},
#     'href': 'https://api.spotify.com/v1/users/qct2gslkz5os8jbwwzj8kebb6',
#     'id': 'qct2gslkz5os8jbwwzj8kebb6',
#     'type': 'user',
#     'uri': 'spotify:user:qct2gslkz5os8jbwwzj8kebb6'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': None,
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'PR',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'PR',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'type': 'album',
#      'album_type': 'album',
#      'href': 'https://api.spotify.com/v1/albums/7kFyd5oyJdVX2pIi6P4iHE',
#      'id': '7kFyd5oyJdVX2pIi6P4iHE',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2735074bd0894cb1340b8d8a678',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e025074bd0894cb1340b8d8a678',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048515074bd0894cb1340b8d8a678',
#        'width': 64}],
#      'name': 'rosie',
#      'release_date': '2024-12-06',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:7kFyd5oyJdVX2pIi6P4iHE',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3eVa5w3URK5duf6eyVDbu9'},
#        'href': 'https://api.spotify.com/v1/artists/3eVa5w3URK5duf6eyVDbu9',
#        'id': '3eVa5w3URK5duf6eyVDbu9',
#        'name': 'ROSÉ',
#        'type': 'artist',
#        'uri': 'spotify:artist:3eVa5w3URK5duf6eyVDbu9'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7kFyd5oyJdVX2pIi6P4iHE'},
#      'total_tracks': 12},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3eVa5w3URK5duf6eyVDbu9'},
#       'href': 'https://api.spotify.com/v1/artists/3eVa5w3URK5duf6eyVDbu9',
#       'id': '3eVa5w3URK5duf6eyVDbu9',
#       'name': 'ROSÉ',
#       'type': 'artist',
#       'uri': 'spotify:artist:3eVa5w3URK5duf6eyVDbu9'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/0du5cEVh5yTK9QJze8zA0C'},
#       'href': 'https://api.spotify.com/v1/artists/0du5cEVh5yTK9QJze8zA0C',
#       'id': '0du5cEVh5yTK9QJze8zA0C',
#       'name': 'Bruno Mars',
#       'type': 'artist',
#       'uri': 'spotify:artist:0du5cEVh5yTK9QJze8zA0C'}],
#     'disc_number': 1,
#     'track_number': 6,
#     'duration_ms': 169917,
#     'external_ids': {'isrc': 'USAT22409172'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4wJ5Qq0jBN4ajy7ouZIV1c'},
#     'href': 'https://api.spotify.com/v1/tracks/4wJ5Qq0jBN4ajy7ouZIV1c',
#     'id': '4wJ5Qq0jBN4ajy7ouZIV1c',
#     'name': 'APT.',
#     'popularity': 91,
#     'uri': 'spotify:track:4wJ5Qq0jBN4ajy7ouZIV1c',
#     'is_local': False},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2025-01-08T02:14:55Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/qct2gslkz5os8jbwwzj8kebb6'},
#     'href': 'https://api.spotify.com/v1/users/qct2gslkz5os8jbwwzj8kebb6',
#     'id': 'qct2gslkz5os8jbwwzj8kebb6',
#     'type': 'user',
#     'uri': 'spotify:user:qct2gslkz5os8jbwwzj8kebb6'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': None,
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'PR',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'explicit': True,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'PR',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'type': 'album',
#      'album_type': 'album',
#      'href': 'https://api.spotify.com/v1/albums/5K79FLRUCSysQnVESLcTdb',
#      'id': '5K79FLRUCSysQnVESLcTdb',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273bbd45c8d36e0e045ef640411',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02bbd45c8d36e0e045ef640411',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851bbd45c8d36e0e045ef640411',
#        'width': 64}],
#      'name': 'DeBÍ TiRAR MáS FOToS',
#      'release_date': '2025-01-05',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:5K79FLRUCSysQnVESLcTdb',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4q3ewBCX7sLwd24euuV69X'},
#        'href': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X',
#        'id': '4q3ewBCX7sLwd24euuV69X',
#        'name': 'Bad Bunny',
#        'type': 'artist',
#        'uri': 'spotify:artist:4q3ewBCX7sLwd24euuV69X'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5K79FLRUCSysQnVESLcTdb'},
#      'total_tracks': 17},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4q3ewBCX7sLwd24euuV69X'},
#       'href': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X',
#       'id': '4q3ewBCX7sLwd24euuV69X',
#       'name': 'Bad Bunny',
#       'type': 'artist',
#       'uri': 'spotify:artist:4q3ewBCX7sLwd24euuV69X'}],
#     'disc_number': 1,
#     'track_number': 16,
#     'duration_ms': 237117,
#     'external_ids': {'isrc': 'QMFMF2447070'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3sK8wGT43QFpWrvNQsrQya'},
#     'href': 'https://api.spotify.com/v1/tracks/3sK8wGT43QFpWrvNQsrQya',
#     'id': '3sK8wGT43QFpWrvNQsrQya',
#     'name': 'DtMF',
#     'popularity': 97,
#     'uri': 'spotify:track:3sK8wGT43QFpWrvNQsrQya',
#     'is_local': False},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2025-03-25T21:30:25Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/qct2gslkz5os8jbwwzj8kebb6'},
#     'href': 'https://api.spotify.com/v1/users/qct2gslkz5os8jbwwzj8kebb6',
#     'id': 'qct2gslkz5os8jbwwzj8kebb6',
#     'type': 'user',
#     'uri': 'spotify:user:qct2gslkz5os8jbwwzj8kebb6'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': None,
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'PR',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'PR',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'type': 'album',
#      'album_type': 'single',
#      'href': 'https://api.spotify.com/v1/albums/0QLILSOq1IqAqx62drmv4E',
#      'id': '0QLILSOq1IqAqx62drmv4E',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2739d24f74c1e2d8a12b1e591ec',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e029d24f74c1e2d8a12b1e591ec',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048519d24f74c1e2d8a12b1e591ec',
#        'width': 64}],
#      'name': 'back to friends',
#      'release_date': '2024-12-27',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:0QLILSOq1IqAqx62drmv4E',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4G9NDjRyZFDlJKMRL8hx3S'},
#        'href': 'https://api.spotify.com/v1/artists/4G9NDjRyZFDlJKMRL8hx3S',
#        'id': '4G9NDjRyZFDlJKMRL8hx3S',
#        'name': 'sombr',
#        'type': 'artist',
#        'uri': 'spotify:artist:4G9NDjRyZFDlJKMRL8hx3S'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0QLILSOq1IqAqx62drmv4E'},
#      'total_tracks': 1},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4G9NDjRyZFDlJKMRL8hx3S'},
#       'href': 'https://api.spotify.com/v1/artists/4G9NDjRyZFDlJKMRL8hx3S',
#       'id': '4G9NDjRyZFDlJKMRL8hx3S',
#       'name': 'sombr',
#       'type': 'artist',
#       'uri': 'spotify:artist:4G9NDjRyZFDlJKMRL8hx3S'}],
#     'disc_number': 1,
#     'track_number': 1,
#     'duration_ms': 199032,
#     'external_ids': {'isrc': 'USWB12405502'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0FTmksd2dxiE5e3rWyJXs6'},
#     'href': 'https://api.spotify.com/v1/tracks/0FTmksd2dxiE5e3rWyJXs6',
#     'id': '0FTmksd2dxiE5e3rWyJXs6',
#     'name': 'back to friends',
#     'popularity': 95,
#     'uri': 'spotify:track:0FTmksd2dxiE5e3rWyJXs6',
#     'is_local': False},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2025-03-05T04:40:18Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/qct2gslkz5os8jbwwzj8kebb6'},
#     'href': 'https://api.spotify.com/v1/users/qct2gslkz5os8jbwwzj8kebb6',
#     'id': 'qct2gslkz5os8jbwwzj8kebb6',
#     'type': 'user',
#     'uri': 'spotify:user:qct2gslkz5os8jbwwzj8kebb6'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': None,
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'PR',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'explicit': True,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'PR',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'type': 'album',
#      'album_type': 'single',
#      'href': 'https://api.spotify.com/v1/albums/4Xdo78uvvt1P7rWRX8TOPt',
#      'id': '4Xdo78uvvt1P7rWRX8TOPt',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2734740100d84f3667f1eae6870',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e024740100d84f3667f1eae6870',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048514740100d84f3667f1eae6870',
#        'width': 64}],
#      'name': 'La Plena (W Sound 05)',
#      'release_date': '2025-02-19',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:4Xdo78uvvt1P7rWRX8TOPt',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5uwa6tAMMfNbBFIHiI6NV4'},
#        'href': 'https://api.spotify.com/v1/artists/5uwa6tAMMfNbBFIHiI6NV4',
#        'id': '5uwa6tAMMfNbBFIHiI6NV4',
#        'name': 'W Sound',
#        'type': 'artist',
#        'uri': 'spotify:artist:5uwa6tAMMfNbBFIHiI6NV4'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/7a0XAaPaK2aDSqa8p3QnC7'},
#        'href': 'https://api.spotify.com/v1/artists/7a0XAaPaK2aDSqa8p3QnC7',
#        'id': '7a0XAaPaK2aDSqa8p3QnC7',
#        'name': 'Beéle',
#        'type': 'artist',
#        'uri': 'spotify:artist:7a0XAaPaK2aDSqa8p3QnC7'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/3m5qlPf2OkihLz3dRYnkPA'},
#        'href': 'https://api.spotify.com/v1/artists/3m5qlPf2OkihLz3dRYnkPA',
#        'id': '3m5qlPf2OkihLz3dRYnkPA',
#        'name': 'Ovy On The Drums',
#        'type': 'artist',
#        'uri': 'spotify:artist:3m5qlPf2OkihLz3dRYnkPA'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4Xdo78uvvt1P7rWRX8TOPt'},
#      'total_tracks': 1},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5uwa6tAMMfNbBFIHiI6NV4'},
#       'href': 'https://api.spotify.com/v1/artists/5uwa6tAMMfNbBFIHiI6NV4',
#       'id': '5uwa6tAMMfNbBFIHiI6NV4',
#       'name': 'W Sound',
# ...
#      'type': 'album',
#      'album_type': 'album',
#      'href': 'https://api.spotify.com/v1/albums/4BbsHmXEghoPPevQjPnHXx',
#      'id': '4BbsHmXEghoPPevQjPnHXx',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27388208159b1b3c69eefdeb2e0',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0288208159b1b3c69eefdeb2e0',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485188208159b1b3c69eefdeb2e0',
#        'width': 64}],
#      'name': 'F-1 Trillion',
#      'release_date': '2024-08-15',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:4BbsHmXEghoPPevQjPnHXx',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/246dkjvS1zLTtiykXe5h60'},
#        'href': 'https://api.spotify.com/v1/artists/246dkjvS1zLTtiykXe5h60',
#        'id': '246dkjvS1zLTtiykXe5h60',
#        'name': 'Post Malone',
#        'type': 'artist',
#        'uri': 'spotify:artist:246dkjvS1zLTtiykXe5h60'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4BbsHmXEghoPPevQjPnHXx'},
#      'total_tracks': 18},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/246dkjvS1zLTtiykXe5h60'},
#       'href': 'https://api.spotify.com/v1/artists/246dkjvS1zLTtiykXe5h60',
#       'id': '246dkjvS1zLTtiykXe5h60',
#       'name': 'Post Malone',
#       'type': 'artist',
#       'uri': 'spotify:artist:246dkjvS1zLTtiykXe5h60'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4oUHIQIBe0LHzYfvXNW4QM'},
#       'href': 'https://api.spotify.com/v1/artists/4oUHIQIBe0LHzYfvXNW4QM',
#       'id': '4oUHIQIBe0LHzYfvXNW4QM',
#       'name': 'Morgan Wallen',
#       'type': 'artist',
#       'uri': 'spotify:artist:4oUHIQIBe0LHzYfvXNW4QM'}],
#     'disc_number': 1,
#     'track_number': 3,
#     'duration_ms': 178205,
#     'external_ids': {'isrc': 'USUM72404990'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5IZXB5IKAD2qlvTPJYDCFB'},
#     'href': 'https://api.spotify.com/v1/tracks/5IZXB5IKAD2qlvTPJYDCFB',
#     'id': '5IZXB5IKAD2qlvTPJYDCFB',
#     'name': 'I Had Some Help (Feat. Morgan Wallen)',
#     'popularity': 87,
#     'uri': 'spotify:track:5IZXB5IKAD2qlvTPJYDCFB',
#     'is_local': False},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2025-01-08T02:14:55Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/qct2gslkz5os8jbwwzj8kebb6'},
#     'href': 'https://api.spotify.com/v1/users/qct2gslkz5os8jbwwzj8kebb6',
#     'id': 'qct2gslkz5os8jbwwzj8kebb6',
#     'type': 'user',
#     'uri': 'spotify:user:qct2gslkz5os8jbwwzj8kebb6'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': None,
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'PR',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'explicit': True,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'PR',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'type': 'album',
#      'album_type': 'album',
#      'href': 'https://api.spotify.com/v1/albums/5K79FLRUCSysQnVESLcTdb',
#      'id': '5K79FLRUCSysQnVESLcTdb',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273bbd45c8d36e0e045ef640411',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02bbd45c8d36e0e045ef640411',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851bbd45c8d36e0e045ef640411',
#        'width': 64}],
#      'name': 'DeBÍ TiRAR MáS FOToS',
#      'release_date': '2025-01-05',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:5K79FLRUCSysQnVESLcTdb',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4q3ewBCX7sLwd24euuV69X'},
#        'href': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X',
#        'id': '4q3ewBCX7sLwd24euuV69X',
#        'name': 'Bad Bunny',
#        'type': 'artist',
#        'uri': 'spotify:artist:4q3ewBCX7sLwd24euuV69X'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5K79FLRUCSysQnVESLcTdb'},
#      'total_tracks': 17},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4q3ewBCX7sLwd24euuV69X'},
#       'href': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X',
#       'id': '4q3ewBCX7sLwd24euuV69X',
#       'name': 'Bad Bunny',
#       'type': 'artist',
#       'uri': 'spotify:artist:4q3ewBCX7sLwd24euuV69X'}],
#     'disc_number': 1,
#     'track_number': 10,
#     'duration_ms': 199114,
#     'external_ids': {'isrc': 'QMFMF2447064'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4MUrUT38U98olfnyzMBCzm'},
#     'href': 'https://api.spotify.com/v1/tracks/4MUrUT38U98olfnyzMBCzm',
#     'id': '4MUrUT38U98olfnyzMBCzm',
#     'name': 'KLOuFRENS',
#     'popularity': 91,
#     'uri': 'spotify:track:4MUrUT38U98olfnyzMBCzm',
#     'is_local': False},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2025-01-02T15:25:39Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/qct2gslkz5os8jbwwzj8kebb6'},
#     'href': 'https://api.spotify.com/v1/users/qct2gslkz5os8jbwwzj8kebb6',
#     'id': 'qct2gslkz5os8jbwwzj8kebb6',
#     'type': 'user',
#     'uri': 'spotify:user:qct2gslkz5os8jbwwzj8kebb6'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': None,
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'type': 'album',
#      'album_type': 'album',
#      'href': 'https://api.spotify.com/v1/albums/20lOt6G8MHv8ZO7ViOmiP7',
#      'id': '20lOt6G8MHv8ZO7ViOmiP7',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2739e2f95ae77cf436017ada9cb',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e029e2f95ae77cf436017ada9cb',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048519e2f95ae77cf436017ada9cb',
#        'width': 64}],
#      'name': 'Native',
#      'release_date': '2013-01-01',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:20lOt6G8MHv8ZO7ViOmiP7',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5Pwc4xIPtQLFEnJriah9YJ'},
#        'href': 'https://api.spotify.com/v1/artists/5Pwc4xIPtQLFEnJriah9YJ',
#        'id': '5Pwc4xIPtQLFEnJriah9YJ',
#        'name': 'OneRepublic',
#        'type': 'artist',
#        'uri': 'spotify:artist:5Pwc4xIPtQLFEnJriah9YJ'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/20lOt6G8MHv8ZO7ViOmiP7'},
#      'total_tracks': 12},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5Pwc4xIPtQLFEnJriah9YJ'},
#       'href': 'https://api.spotify.com/v1/artists/5Pwc4xIPtQLFEnJriah9YJ',
#       'id': '5Pwc4xIPtQLFEnJriah9YJ',
#       'name': 'OneRepublic',
#       'type': 'artist',
#       'uri': 'spotify:artist:5Pwc4xIPtQLFEnJriah9YJ'}],
#     'disc_number': 1,
#     'track_number': 1,
#     'duration_ms': 257265,
#     'external_ids': {'isrc': 'USUM71301306'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2tpWsVSb9UEmDRxAl1zhX1'},
#     'href': 'https://api.spotify.com/v1/tracks/2tpWsVSb9UEmDRxAl1zhX1',
#     'id': '2tpWsVSb9UEmDRxAl1zhX1',
#     'name': 'Counting Stars',
#     'popularity': 90,
#     'uri': 'spotify:track:2tpWsVSb9UEmDRxAl1zhX1',
#     'is_local': False},
#    'video_thumbnail': {'url': None}}],
#  'limit': 100,
#  'next': 'https://api.spotify.com/v1/playlists/4yNfFAuHcSgzbcSm6q5QDu/tracks?offset=100&limit=100&additional_types=track',
#  'offset': 0,
#  'previous': None,
#  'total': 200}

# %%
# get all album data into a list
album_list = []
for row in data['items']:
    album_element = {
        'album_id':row['track']['album']['id'],
        'album_name':row['track']['album']['name'],
        'album_release_date':row['track']['album']['release_date'],
        'album_total_tracks':row['track']['album']['total_tracks'],
        'album_url':row['track']['album']['external_urls']['spotify'],
    }
    album_list.append(album_element)

album_list
# Out:
# [{'album_id': '1eCGY9WJpYgtaFh1Lk2KNo',
#   'album_name': "You'll Be Alright, Kid (Chapter 1)",
#   'album_release_date': '2024-09-26',
#   'album_total_tracks': 11,
#   'album_url': 'https://open.spotify.com/album/1eCGY9WJpYgtaFh1Lk2KNo'},
#  {'album_id': '2MHUaRi9OCyTN02SoyRRBJ',
#   'album_name': 'MAYHEM',
#   'album_release_date': '2025-03-07',
#   'album_total_tracks': 14,
#   'album_url': 'https://open.spotify.com/album/2MHUaRi9OCyTN02SoyRRBJ'},
#  {'album_id': '7aJuG4TFXa2hmE4z1yxc3n',
#   'album_name': 'HIT ME HARD AND SOFT',
#   'album_release_date': '2024-05-17',
#   'album_total_tracks': 10,
#   'album_url': 'https://open.spotify.com/album/7aJuG4TFXa2hmE4z1yxc3n'},
#  {'album_id': '7kFyd5oyJdVX2pIi6P4iHE',
#   'album_name': 'rosie',
#   'album_release_date': '2024-12-06',
#   'album_total_tracks': 12,
#   'album_url': 'https://open.spotify.com/album/7kFyd5oyJdVX2pIi6P4iHE'},
#  {'album_id': '5K79FLRUCSysQnVESLcTdb',
#   'album_name': 'DeBÍ TiRAR MáS FOToS',
#   'album_release_date': '2025-01-05',
#   'album_total_tracks': 17,
#   'album_url': 'https://open.spotify.com/album/5K79FLRUCSysQnVESLcTdb'},
#  {'album_id': '0QLILSOq1IqAqx62drmv4E',
#   'album_name': 'back to friends',
#   'album_release_date': '2024-12-27',
#   'album_total_tracks': 1,
#   'album_url': 'https://open.spotify.com/album/0QLILSOq1IqAqx62drmv4E'},
#  {'album_id': '4Xdo78uvvt1P7rWRX8TOPt',
#   'album_name': 'La Plena (W Sound 05)',
#   'album_release_date': '2025-02-19',
#   'album_total_tracks': 1,
#   'album_url': 'https://open.spotify.com/album/4Xdo78uvvt1P7rWRX8TOPt'},
#  {'album_id': '19m6pwPmwNFSPV7wtHtg7D',
#   'album_name': 'undressed',
#   'album_release_date': '2025-03-21',
#   'album_total_tracks': 1,
#   'album_url': 'https://open.spotify.com/album/19m6pwPmwNFSPV7wtHtg7D'},
#  {'album_id': '5K79FLRUCSysQnVESLcTdb',
#   'album_name': 'DeBÍ TiRAR MáS FOToS',
#   'album_release_date': '2025-01-05',
#   'album_total_tracks': 17,
#   'album_url': 'https://open.spotify.com/album/5K79FLRUCSysQnVESLcTdb'},
#  {'album_id': '1vWMw6pu3err6qqZzI3RhH',
#   'album_name': 'Ruby',
#   'album_release_date': '2025-03-07',
#   'album_total_tracks': 15,
#   'album_url': 'https://open.spotify.com/album/1vWMw6pu3err6qqZzI3RhH'},
#  {'album_id': '7aJuG4TFXa2hmE4z1yxc3n',
#   'album_name': 'HIT ME HARD AND SOFT',
#   'album_release_date': '2024-05-17',
#   'album_total_tracks': 10,
#   'album_url': 'https://open.spotify.com/album/7aJuG4TFXa2hmE4z1yxc3n'},
#  {'album_id': '6XVW3zoK1nmskW7drvHy9h',
#   'album_name': 'Nalar',
#   'album_release_date': '2023-04-18',
#   'album_total_tracks': 10,
#   'album_url': 'https://open.spotify.com/album/6XVW3zoK1nmskW7drvHy9h'},
#  {'album_id': '0hBRqPYPXhr1RkTDG3n4Mk',
#   'album_name': 'The Secret of Us (Deluxe)',
#   'album_release_date': '2024-10-18',
#   'album_total_tracks': 20,
#   'album_url': 'https://open.spotify.com/album/0hBRqPYPXhr1RkTDG3n4Mk'},
#  {'album_id': '0hvT3yIEysuuvkK73vgdcW',
#   'album_name': 'GNX',
#   'album_release_date': '2024-11-22',
#   'album_total_tracks': 12,
#   'album_url': 'https://open.spotify.com/album/0hvT3yIEysuuvkK73vgdcW'},
#  {'album_id': '4DWrYvfGXRE8ko5ZxlIpit',
#   'album_name': 'Sailor Song',
#   'album_release_date': '2024-07-26',
#   'album_total_tracks': 1,
#   'album_url': 'https://open.spotify.com/album/4DWrYvfGXRE8ko5ZxlIpit'},
#  {'album_id': '168CdR21lfn0TTyw1Pkdcm',
#   'album_name': 'Fireworks & Rollerblades',
#   'album_release_date': '2024-04-05',
#   'album_total_tracks': 15,
#   'album_url': 'https://open.spotify.com/album/168CdR21lfn0TTyw1Pkdcm'},
#  {'album_id': '15XcLhiVMlSOipUddTNDnr',
#   'album_name': 'MUSE',
#   'album_release_date': '2024-07-19',
#   'album_total_tracks': 7,
#   'album_url': 'https://open.spotify.com/album/15XcLhiVMlSOipUddTNDnr'},
#  {'album_id': '2MHUaRi9OCyTN02SoyRRBJ',
#   'album_name': 'MAYHEM',
#   'album_release_date': '2025-03-07',
#   'album_total_tracks': 14,
#   'album_url': 'https://open.spotify.com/album/2MHUaRi9OCyTN02SoyRRBJ'},
#  {'album_id': '3iPSVi54hsacKKl1xIR2eH',
#   'album_name': "Short n' Sweet",
#   'album_release_date': '2024-08-23',
#   'album_total_tracks': 12,
#   'album_url': 'https://open.spotify.com/album/3iPSVi54hsacKKl1xIR2eH'},
#  {'album_id': '1uE3dRPe3SrGdNhd1nWlSa',
#   'album_name': "Bird's Eye",
#   'album_release_date': '2024-08-09',
#   'album_total_tracks': 11,
#   'album_url': 'https://open.spotify.com/album/1uE3dRPe3SrGdNhd1nWlSa'},
#  {'album_id': '3uTpTaMOynCYKV5AtgeO2U',
#   'album_name': "This Wasn't Meant For You Anyway",
#   'album_release_date': '2024-06-21',
#   'album_total_tracks': 11,
#   'album_url': 'https://open.spotify.com/album/3uTpTaMOynCYKV5AtgeO2U'},
#  {'album_id': '3OxfaVgvTxUTy7276t7SPU',
#   'album_name': 'Hurry Up Tomorrow',
#   'album_release_date': '2025-01-31',
#   'album_total_tracks': 22,
#   'album_url': 'https://open.spotify.com/album/3OxfaVgvTxUTy7276t7SPU'},
#  {'album_id': '5K79FLRUCSysQnVESLcTdb',
#   'album_name': 'DeBÍ TiRAR MáS FOToS',
#   'album_release_date': '2025-01-05',
#   'album_total_tracks': 17,
#   'album_url': 'https://open.spotify.com/album/5K79FLRUCSysQnVESLcTdb'},
#  {'album_id': '7tzVd1fwkxsorytCBjEJkU',
#   'album_name': 'The Idol Episode 4 (Music from the HBO Original Series)',
#   'album_release_date': '2023-06-23',
#   'album_total_tracks': 3,
#   'album_url': 'https://open.spotify.com/album/7tzVd1fwkxsorytCBjEJkU'},
#  {'album_id': '3pLdWdkj83EYfDN6H2N8MR',
#   'album_name': 'Black Panther The Album Music From And Inspired By',
#   'album_release_date': '2018-02-09',
#   'album_total_tracks': 14,
#   'album_url': 'https://open.spotify.com/album/3pLdWdkj83EYfDN6H2N8MR'},
#  {'album_id': '7nacKlk586eLRBSIsrk9DB',
#   'album_name': "I've Tried Everything But Therapy (Part 1)",
#   'album_release_date': '2023-09-15',
#   'album_total_tracks': 10,
#   'album_url': 'https://open.spotify.com/album/7nacKlk586eLRBSIsrk9DB'},
#  {'album_id': '4gyYKUIAOEcP50RM1Sjzj6',
#   'album_name': 'Show Me Love',
#   'album_release_date': '2025-02-07',
#   'album_total_tracks': 1,
#   'album_url': 'https://open.spotify.com/album/4gyYKUIAOEcP50RM1Sjzj6'},
#  {'album_id': '5yPu6XkHu8DAGmV6YkXYZq',
#   'album_name': 'Alligator Bites Never Heal (Extended)',
#   'album_release_date': '2025-03-14',
#   'album_total_tracks': 20,
#   'album_url': 'https://open.spotify.com/album/5yPu6XkHu8DAGmV6YkXYZq'},
#  {'album_id': '6Rl6YoCarF2GHPSQmmFjuR',
#   'album_name': '$ome $exy $ongs 4 U',
#   'album_release_date': '2025-02-14',
#   'album_total_tracks': 21,
#   'album_url': 'https://open.spotify.com/album/6Rl6YoCarF2GHPSQmmFjuR'},
#  {'album_id': '4UMjBXcRqIgMZ1XumU2x5T',
#   'album_name': 'Dizzy up the Girl',
#   'album_release_date': '1998',
#   'album_total_tracks': 13,
#   'album_url': 'https://open.spotify.com/album/4UMjBXcRqIgMZ1XumU2x5T'},
#  {'album_id': '5K79FLRUCSysQnVESLcTdb',
#   'album_name': 'DeBÍ TiRAR MáS FOToS',
#   'album_release_date': '2025-01-05',
#   'album_total_tracks': 17,
#   'album_url': 'https://open.spotify.com/album/5K79FLRUCSysQnVESLcTdb'},
#  {'album_id': '1WAjjRMfZjEXtB0lQrAw6Q',
#   'album_name': 'Good Luck, Babe!',
#   'album_release_date': '2024-04-05',
#   'album_total_tracks': 1,
#   'album_url': 'https://open.spotify.com/album/1WAjjRMfZjEXtB0lQrAw6Q'},
#  {'album_id': '78bpIziExqiI9qztvNFlQu',
#   'album_name': 'AM',
#   'album_release_date': '2013-09-09',
#   'album_total_tracks': 12,
#   'album_url': 'https://open.spotify.com/album/78bpIziExqiI9qztvNFlQu'},
#  {'album_id': '4xkM0BwLM9H2IUcbYzpcBI',
#   'album_name': 'I Love You.',
#   'album_release_date': '2013-04-22',
#   'album_total_tracks': 11,
#   'album_url': 'https://open.spotify.com/album/4xkM0BwLM9H2IUcbYzpcBI'},
#  {'album_id': '7GZpa8xckIRPFIbT49B4zZ',
#   'album_name': "You'll Be In My Heart",
#   'album_release_date': '2022-09-14',
#   'album_total_tracks': 2,
#   'album_url': 'https://open.spotify.com/album/7GZpa8xckIRPFIbT49B4zZ'},
#  {'album_id': '4sD1qg4jwTZR4mvR4Iflk5',
#   'album_name': 'Strange Trails',
#   'album_release_date': '2015-04-06',
#   'album_total_tracks': 14,
#   'album_url': 'https://open.spotify.com/album/4sD1qg4jwTZR4mvR4Iflk5'},
#  {'album_id': '5ylbxH7EqpsmHZCRuiYewS',
#   'album_name': 'Si Antes Te Hubiera Conocido',
#   'album_release_date': '2024-06-21',
#   'album_total_tracks': 1,
#   'album_url': 'https://open.spotify.com/album/5ylbxH7EqpsmHZCRuiYewS'},
#  {'album_id': '1JpJzuM4uncCfCimVozkmy',
#   'album_name': '111XPANTIA',
#   'album_release_date': '2025-05-02',
#   'album_total_tracks': 12,
#   'album_url': 'https://open.spotify.com/album/1JpJzuM4uncCfCimVozkmy'},
#  {'album_id': '5JjnoGJyOxfSZUZtk2rRwZ',
#   'album_name': 'Not Like Us',
#   'album_release_date': '2024-05-04',
#   'album_total_tracks': 1,
#   'album_url': 'https://open.spotify.com/album/5JjnoGJyOxfSZUZtk2rRwZ'},
#  {'album_id': '338NDGMHtB4t5mp8RhMnh3',
#   'album_name': 'Mi Vida Mi Muerte',
#   'album_release_date': '2025-02-14',
#   'album_total_tracks': 21,
#   'album_url': 'https://open.spotify.com/album/338NDGMHtB4t5mp8RhMnh3'},
#  {'album_id': '5W9OT0a5iZlBr83a9WMKFY',
#   'album_name': 'Synchronicity (Remastered 2003)',
#   'album_release_date': '1983-06-17',
#   'album_total_tracks': 11,
#   'album_url': 'https://open.spotify.com/album/5W9OT0a5iZlBr83a9WMKFY'},
#  {'album_id': '5K79FLRUCSysQnVESLcTdb',
#   'album_name': 'DeBÍ TiRAR MáS FOToS',
#   'album_release_date': '2025-01-05',
#   'album_total_tracks': 17,
#   'album_url': 'https://open.spotify.com/album/5K79FLRUCSysQnVESLcTdb'},
#  {'album_id': '2YgSHCBlOE0ZamNGQBg19Q',
#   'album_name': 'De Vuelta a las Andadas',
#   'album_release_date': '2025-05-09',
#   'album_total_tracks': 18,
#   'album_url': 'https://open.spotify.com/album/2YgSHCBlOE0ZamNGQBg19Q'},
#  {'album_id': '03guxdOi12XJbnvxvxbpwG',
#   'album_name': 'Submarine',
#   'album_release_date': '2024-05-31',
#   'album_total_tracks': 14,
#   'album_url': 'https://open.spotify.com/album/03guxdOi12XJbnvxvxbpwG'},
#  {'album_id': '25oD4E4cwmG7SCQIoF3ez5',
#   'album_name': 'Gnarly',
#   'album_release_date': '2025-04-30',
#   'album_total_tracks': 1,
#   'album_url': 'https://open.spotify.com/album/25oD4E4cwmG7SCQIoF3ez5'},
#  {'album_id': '6KaEpgeZQF6ZVVAmSoZUrb',
#   'album_name': 'So Close To What',
#   'album_release_date': '2025-02-24',
#   'album_total_tracks': 16,
#   'album_url': 'https://open.spotify.com/album/6KaEpgeZQF6ZVVAmSoZUrb'},
#  {'album_id': '0XKconI47eiBP6qPYHsx9f',
#   'album_name': 'The Rise and Fall of a Midwest Princess',
#   'album_release_date': '2023-09-21',
#   'album_total_tracks': 14,
#   'album_url': 'https://open.spotify.com/album/0XKconI47eiBP6qPYHsx9f'},
#  {'album_id': '5K79FLRUCSysQnVESLcTdb',
#   'album_name': 'DeBÍ TiRAR MáS FOToS',
#   'album_release_date': '2025-01-05',
#   'album_total_tracks': 17,
#   'album_url': 'https://open.spotify.com/album/5K79FLRUCSysQnVESLcTdb'},
#  {'album_id': '0I7096R74VFP2xnMmp33sY',
#   'album_name': 'PASSO BEM SOLTO',
#   'album_release_date': '2024-04-23',
#   'album_total_tracks': 5,
#   'album_url': 'https://open.spotify.com/album/0I7096R74VFP2xnMmp33sY'},
#  {'album_id': '34OOEmWpj7OnO5kCfal1MO',
#   'album_name': 'MIJA NO TE ASUSTES',
#   'album_release_date': '2025-02-20',
#   'album_total_tracks': 16,
#   'album_url': 'https://open.spotify.com/album/34OOEmWpj7OnO5kCfal1MO'},
#  {'album_id': '2nkto6YNI4rUYTLqEwWJ3o',
#   'album_name': 'Flower Boy',
#   'album_release_date': '2017-07-21',
#   'album_total_tracks': 14,
#   'album_url': 'https://open.spotify.com/album/2nkto6YNI4rUYTLqEwWJ3o'},
#  {'album_id': '6ZG5lRT77aJ3btmArcykra',
#   'album_name': 'Parachutes',
#   'album_release_date': '2000-07-10',
#   'album_total_tracks': 10,
#   'album_url': 'https://open.spotify.com/album/6ZG5lRT77aJ3btmArcykra'},
#  {'album_id': '1JpJzuM4uncCfCimVozkmy',
#   'album_name': '111XPANTIA',
#   'album_release_date': '2025-05-02',
#   'album_total_tracks': 12,
#   'album_url': 'https://open.spotify.com/album/1JpJzuM4uncCfCimVozkmy'},
#  {'album_id': '3P4SQqMMgjqfqVxgLwtYRk',
#   'album_name': 'Unreal Unearth: Unheard',
#   'album_release_date': '2024-03-22',
#   'album_total_tracks': 20,
#   'album_url': 'https://open.spotify.com/album/3P4SQqMMgjqfqVxgLwtYRk'},
#  {'album_id': '3a9qH2VEsSiOZvMrjaS0Nu',
#   'album_name': "how i'm feeling now",
#   'album_release_date': '2020-05-15',
#   'album_total_tracks': 11,
#   'album_url': 'https://open.spotify.com/album/3a9qH2VEsSiOZvMrjaS0Nu'},
#  {'album_id': '1qwlxZTNLe1jq3b0iidlue',
#   'album_name': 'The Fame',
#   'album_release_date': '2008-01-01',
#   'album_total_tracks': 15,
#   'album_url': 'https://open.spotify.com/album/1qwlxZTNLe1jq3b0iidlue'},
#  {'album_id': '5aelly3dAJd7yZlgUHpLBw',
#   'album_name': 'blue',
#   'album_release_date': '2024-08-02',
#   'album_total_tracks': 1,
#   'album_url': 'https://open.spotify.com/album/5aelly3dAJd7yZlgUHpLBw'},
#  {'album_id': '1XkGORuUX2QGOEIL4EbJKm',
#   'album_name': 'Favourite Worst Nightmare',
#   'album_release_date': '2007-04-22',
#   'album_total_tracks': 12,
#   'album_url': 'https://open.spotify.com/album/1XkGORuUX2QGOEIL4EbJKm'},
#  {'album_id': '5utxE1ImIDJFXRHf137hoy',
#   'album_name': 'MALA MÍA',
#   'album_release_date': '2024-12-19',
#   'album_total_tracks': 5,
#   'album_url': 'https://open.spotify.com/album/5utxE1ImIDJFXRHf137hoy'},
#  {'album_id': '6LY3AerY6KNGOPsNPL63Kk',
#   'album_name': 'Born This Way (International Special Edition Version)',
#   'album_release_date': '2011-05-23',
#   'album_total_tracks': 23,
#   'album_url': 'https://open.spotify.com/album/6LY3AerY6KNGOPsNPL63Kk'},
#  {'album_id': '3iPSVi54hsacKKl1xIR2eH',
#   'album_name': "Short n' Sweet",
#   'album_release_date': '2024-08-23',
#   'album_total_tracks': 12,
#   'album_url': 'https://open.spotify.com/album/3iPSVi54hsacKKl1xIR2eH'},
#  {'album_id': '5pSk3c3wVwnb2arb6ohCPU',
#   'album_name': 'GOLDEN',
#   'album_release_date': '2023-11-03',
#   'album_total_tracks': 11,
#   'album_url': 'https://open.spotify.com/album/5pSk3c3wVwnb2arb6ohCPU'},
#  {'album_id': '0L0WsHBFK6x1FdsobtH9Ko',
#   'album_name': 'Redención',
#   'album_release_date': '2025-05-08',
#   'album_total_tracks': 14,
#   'album_url': 'https://open.spotify.com/album/0L0WsHBFK6x1FdsobtH9Ko'},
#  {'album_id': '1CEODgTmTwLyabvwd7HBty',
#   'album_name': 'Viva La Vida or Death and All His Friends',
#   'album_release_date': '2008-06-06',
#   'album_total_tracks': 10,
#   'album_url': 'https://open.spotify.com/album/1CEODgTmTwLyabvwd7HBty'},
#  {'album_id': '6KaEpgeZQF6ZVVAmSoZUrb',
#   'album_name': 'So Close To What',
#   'album_release_date': '2025-02-24',
#   'album_total_tracks': 16,
#   'album_url': 'https://open.spotify.com/album/6KaEpgeZQF6ZVVAmSoZUrb'},
#  {'album_id': '0aX0UXrHG2ceYIxTQcqJdA',
#   'album_name': 'Cosa Nuestra',
#   'album_release_date': '2024-11-15',
#   'album_total_tracks': 18,
#   'album_url': 'https://open.spotify.com/album/0aX0UXrHG2ceYIxTQcqJdA'},
#  {'album_id': '6MikZBKCtKfPM4439yzBRz',
#   'album_name': 'EL COMIENZO',
#   'album_release_date': '2024-08-09',
#   'album_total_tracks': 7,
#   'album_url': 'https://open.spotify.com/album/6MikZBKCtKfPM4439yzBRz'},
#  {'album_id': '0sWJ3v0FROzcNzyjNYUs6t',
#   'album_name': 'LA CIUDAD',
#   'album_release_date': '2024-12-24',
#   'album_total_tracks': 12,
#   'album_url': 'https://open.spotify.com/album/0sWJ3v0FROzcNzyjNYUs6t'},
#  {'album_id': '3gBVdu4a1MMJVMy6vwPEb8',
#   'album_name': 'Pablo Honey',
#   'album_release_date': '1993-02-22',
#   'album_total_tracks': 12,
#   'album_url': 'https://open.spotify.com/album/3gBVdu4a1MMJVMy6vwPEb8'},
#  {'album_id': '6kvSdLjli85tMwW4jlCN0o',
#   'album_name': "I've Tried Everything But Therapy (Part 2)",
#   'album_release_date': '2025-01-24',
#   'album_total_tracks': 13,
#   'album_url': 'https://open.spotify.com/album/6kvSdLjli85tMwW4jlCN0o'},
#  {'album_id': '34OOEmWpj7OnO5kCfal1MO',
#   'album_name': 'MIJA NO TE ASUSTES',
#   'album_release_date': '2025-02-20',
#   'album_total_tracks': 16,
#   'album_url': 'https://open.spotify.com/album/34OOEmWpj7OnO5kCfal1MO'},
#  {'album_id': '7y5UZkCSxTUo47pxeTWbXK',
#   'album_name': 'Mystical Magical',
#   'album_release_date': '2025-04-24',
#   'album_total_tracks': 1,
#   'album_url': 'https://open.spotify.com/album/7y5UZkCSxTUo47pxeTWbXK'},
#  {'album_id': '2WOyuTsNHF90SryrS3kmIN',
#   'album_name': 'Silakbo',
#   'album_release_date': '2025-01-17',
#   'album_total_tracks': 10,
#   'album_url': 'https://open.spotify.com/album/2WOyuTsNHF90SryrS3kmIN'},
#  {'album_id': '15gT6ikjvzrlIxQ5eTpqLJ',
#   'album_name': 'The Days (NOTION Remix)',
#   'album_release_date': '2024-11-08',
#   'album_total_tracks': 2,
#   'album_url': 'https://open.spotify.com/album/15gT6ikjvzrlIxQ5eTpqLJ'},
#  {'album_id': '2ODvWsOgouMbaA5xf0RkJe',
#   'album_name': 'Starboy',
#   'album_release_date': '2016-11-25',
#   'album_total_tracks': 18,
#   'album_url': 'https://open.spotify.com/album/2ODvWsOgouMbaA5xf0RkJe'},
#  {'album_id': '0DLvFVIfwt3OHdK9kGeEM3',
#   'album_name': "Where I've Been, Isn't Where I'm Going",
#   'album_release_date': '2024-05-31',
#   'album_total_tracks': 12,
#   'album_url': 'https://open.spotify.com/album/0DLvFVIfwt3OHdK9kGeEM3'},
#  {'album_id': '5EYKrEDnKhhcNxGedaRQeK',
#   'album_name': 'eternal sunshine',
#   'album_release_date': '2024-03-08',
#   'album_total_tracks': 13,
#   'album_url': 'https://open.spotify.com/album/5EYKrEDnKhhcNxGedaRQeK'},
#  {'album_id': '3VNxRarx9HUI5w7DHv0TBj',
#   'album_name': 'Stargazing',
#   'album_release_date': '2024-05-10',
#   'album_total_tracks': 1,
#   'album_url': 'https://open.spotify.com/album/3VNxRarx9HUI5w7DHv0TBj'},
#  {'album_id': '0hvT3yIEysuuvkK73vgdcW',
#   'album_name': 'GNX',
#   'album_release_date': '2024-11-22',
#   'album_total_tracks': 12,
#   'album_url': 'https://open.spotify.com/album/0hvT3yIEysuuvkK73vgdcW'},
#  {'album_id': '5HKEezqSNuJSD5Nbrs9bhG',
#   'album_name': 'Lesung Pipi',
#   'album_release_date': '2023-08-31',
#   'album_total_tracks': 1,
#   'album_url': 'https://open.spotify.com/album/5HKEezqSNuJSD5Nbrs9bhG'},
#  {'album_id': '00xSzSrckgOgVAqZUIcrxf',
#   'album_name': 'WITHERED',
#   'album_release_date': '2025-04-25',
#   'album_total_tracks': 15,
#   'album_url': 'https://open.spotify.com/album/00xSzSrckgOgVAqZUIcrxf'},
#  {'album_id': '37HwcDtLqY2WXN7NArODvI',
#   'album_name': 'Azizam',
#   'album_release_date': '2025-04-04',
#   'album_total_tracks': 1,
#   'album_url': 'https://open.spotify.com/album/37HwcDtLqY2WXN7NArODvI'},
#  {'album_id': '38PKSUSFXnO4mbUhLC4ELZ',
#   'album_name': "Sorry I'm Here For Someone Else",
#   'album_release_date': '2025-02-27',
#   'album_total_tracks': 1,
#   'album_url': 'https://open.spotify.com/album/38PKSUSFXnO4mbUhLC4ELZ'},
#  {'album_id': '6hPkbAV3ZXpGZBGUvL6jVM',
#   'album_name': 'Hybrid Theory (Bonus Edition)',
#   'album_release_date': '2000-10-24',
#   'album_total_tracks': 15,
#   'album_url': 'https://open.spotify.com/album/6hPkbAV3ZXpGZBGUvL6jVM'},
#  {'album_id': '0U28P0QVB1QRxpqp5IHOlH',
#   'album_name': 'CHROMAKOPIA',
#   'album_release_date': '2024-10-28',
#   'album_total_tracks': 14,
#   'album_url': 'https://open.spotify.com/album/0U28P0QVB1QRxpqp5IHOlH'},
#  {'album_id': '4sLtOBOzn4s3GDUv3c5oJD',
#   'album_name': 'A Star Is Born Soundtrack',
#   'album_release_date': '2018-10-05',
#   'album_total_tracks': 34,
#   'album_url': 'https://open.spotify.com/album/4sLtOBOzn4s3GDUv3c5oJD'},
#  {'album_id': '1xn54DMo2qIqBuMqHtUsFd',
#   'album_name': 'x (Deluxe Edition)',
#   'album_release_date': '2014-06-21',
#   'album_total_tracks': 16,
#   'album_url': 'https://open.spotify.com/album/1xn54DMo2qIqBuMqHtUsFd'},
#  {'album_id': '1rsjecCzLbJS7YVALG6I7P',
#   'album_name': 'Triple Lavada',
#   'album_release_date': '2025-03-28',
#   'album_total_tracks': 1,
#   'album_url': 'https://open.spotify.com/album/1rsjecCzLbJS7YVALG6I7P'},
#  {'album_id': '6jf5qinEHzsxyBQgvrW916',
#   'album_name': 'VITAMINA',
#   'album_release_date': '2025-02-27',
#   'album_total_tracks': 1,
#   'album_url': 'https://open.spotify.com/album/6jf5qinEHzsxyBQgvrW916'},
#  {'album_id': '6ylFfzx32ICw4L1A7YWNLN',
#   'album_name': 'OASIS',
#   'album_release_date': '2019-06-28',
#   'album_total_tracks': 8,
#   'album_url': 'https://open.spotify.com/album/6ylFfzx32ICw4L1A7YWNLN'},
#  {'album_id': '4JDXBZdRPId4devseaAOKH',
#   'album_name': 'DECIDE',
#   'album_release_date': '2022-09-16',
#   'album_total_tracks': 13,
#   'album_url': 'https://open.spotify.com/album/4JDXBZdRPId4devseaAOKH'},
#  {'album_id': '338NDGMHtB4t5mp8RhMnh3',
#   'album_name': 'Mi Vida Mi Muerte',
#   'album_release_date': '2025-02-14',
#   'album_total_tracks': 21,
#   'album_url': 'https://open.spotify.com/album/338NDGMHtB4t5mp8RhMnh3'},
#  {'album_id': '7BnNV4WZAG7rFqUeMHRdUP',
#   'album_name': 'Dark Thoughts',
#   'album_release_date': '2025-03-14',
#   'album_total_tracks': 1,
#   'album_url': 'https://open.spotify.com/album/7BnNV4WZAG7rFqUeMHRdUP'},
#  {'album_id': '5bP82ZIls6rzhpf5Qu6AzC',
#   'album_name': 'Cigarettes After Sex',
#   'album_release_date': '2017-06-09',
#   'album_total_tracks': 10,
#   'album_url': 'https://open.spotify.com/album/5bP82ZIls6rzhpf5Qu6AzC'},
#  {'album_id': '0Gf1yE895FKK4YWVRuAeg8',
#   'album_name': 'Long Way Down (Deluxe)',
#   'album_release_date': '2013-06-24',
#   'album_total_tracks': 15,
#   'album_url': 'https://open.spotify.com/album/0Gf1yE895FKK4YWVRuAeg8'},
#  {'album_id': '7jhHpyhKorvt65mYvuhlBs',
#   'album_name': 'Shake It To The Max (FLY) (Remix)',
#   'album_release_date': '2025-02-21',
#   'album_total_tracks': 1,
#   'album_url': 'https://open.spotify.com/album/7jhHpyhKorvt65mYvuhlBs'},
#  {'album_id': '3iPSVi54hsacKKl1xIR2eH',
#   'album_name': "Short n' Sweet",
#   'album_release_date': '2024-08-23',
#   'album_total_tracks': 12,
#   'album_url': 'https://open.spotify.com/album/3iPSVi54hsacKKl1xIR2eH'},
#  {'album_id': '4BbsHmXEghoPPevQjPnHXx',
#   'album_name': 'F-1 Trillion',
#   'album_release_date': '2024-08-15',
#   'album_total_tracks': 18,
#   'album_url': 'https://open.spotify.com/album/4BbsHmXEghoPPevQjPnHXx'},
#  {'album_id': '5K79FLRUCSysQnVESLcTdb',
#   'album_name': 'DeBÍ TiRAR MáS FOToS',
#   'album_release_date': '2025-01-05',
#   'album_total_tracks': 17,
#   'album_url': 'https://open.spotify.com/album/5K79FLRUCSysQnVESLcTdb'},
#  {'album_id': '20lOt6G8MHv8ZO7ViOmiP7',
#   'album_name': 'Native',
#   'album_release_date': '2013-01-01',
#   'album_total_tracks': 12,
#   'album_url': 'https://open.spotify.com/album/20lOt6G8MHv8ZO7ViOmiP7'}]

# %%
# get all artists into a list
artist_list = []
for row in data['items']:
    for key,value in row.items():
        if key == 'track':
            for artist in value['artists']:
                artist_dict = {
                    'artist_id': artist['id'],
                    'artist_name': artist['name'],
                    'artist_external_url': artist['external_urls']["spotify"]
                }
                artist_list.append(artist_dict)             
    
artist_list
# Out:
# [{'artist_id': '0fTSzq9jAh4c36UVb4V7CB',
#   'artist_name': 'Alex Warren',
#   'artist_external_url': 'https://open.spotify.com/artist/0fTSzq9jAh4c36UVb4V7CB'},
#  {'artist_id': '1HY2Jd0NmPuamShAr6KMms',
#   'artist_name': 'Lady Gaga',
#   'artist_external_url': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#  {'artist_id': '0du5cEVh5yTK9QJze8zA0C',
#   'artist_name': 'Bruno Mars',
#   'artist_external_url': 'https://open.spotify.com/artist/0du5cEVh5yTK9QJze8zA0C'},
#  {'artist_id': '6qqNVTkY8uBg9cP3Jd7DAH',
#   'artist_name': 'Billie Eilish',
#   'artist_external_url': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#  {'artist_id': '3eVa5w3URK5duf6eyVDbu9',
#   'artist_name': 'ROSÉ',
#   'artist_external_url': 'https://open.spotify.com/artist/3eVa5w3URK5duf6eyVDbu9'},
#  {'artist_id': '0du5cEVh5yTK9QJze8zA0C',
#   'artist_name': 'Bruno Mars',
#   'artist_external_url': 'https://open.spotify.com/artist/0du5cEVh5yTK9QJze8zA0C'},
#  {'artist_id': '4q3ewBCX7sLwd24euuV69X',
#   'artist_name': 'Bad Bunny',
#   'artist_external_url': 'https://open.spotify.com/artist/4q3ewBCX7sLwd24euuV69X'},
#  {'artist_id': '4G9NDjRyZFDlJKMRL8hx3S',
#   'artist_name': 'sombr',
#   'artist_external_url': 'https://open.spotify.com/artist/4G9NDjRyZFDlJKMRL8hx3S'},
#  {'artist_id': '5uwa6tAMMfNbBFIHiI6NV4',
#   'artist_name': 'W Sound',
#   'artist_external_url': 'https://open.spotify.com/artist/5uwa6tAMMfNbBFIHiI6NV4'},
#  {'artist_id': '7a0XAaPaK2aDSqa8p3QnC7',
#   'artist_name': 'Beéle',
#   'artist_external_url': 'https://open.spotify.com/artist/7a0XAaPaK2aDSqa8p3QnC7'},
#  {'artist_id': '3m5qlPf2OkihLz3dRYnkPA',
#   'artist_name': 'Ovy On The Drums',
#   'artist_external_url': 'https://open.spotify.com/artist/3m5qlPf2OkihLz3dRYnkPA'},
#  {'artist_id': '4G9NDjRyZFDlJKMRL8hx3S',
#   'artist_name': 'sombr',
#   'artist_external_url': 'https://open.spotify.com/artist/4G9NDjRyZFDlJKMRL8hx3S'},
#  {'artist_id': '4q3ewBCX7sLwd24euuV69X',
#   'artist_name': 'Bad Bunny',
#   'artist_external_url': 'https://open.spotify.com/artist/4q3ewBCX7sLwd24euuV69X'},
#  {'artist_id': '250b0Wlc5Vk0CoUsaCY84M',
#   'artist_name': 'JENNIE',
#   'artist_external_url': 'https://open.spotify.com/artist/250b0Wlc5Vk0CoUsaCY84M'},
#  {'artist_id': '6qqNVTkY8uBg9cP3Jd7DAH',
#   'artist_name': 'Billie Eilish',
#   'artist_external_url': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#  {'artist_id': '46cVq2dwPgzPE3X1VR9TMj',
#   'artist_name': 'Fourtwnty',
#   'artist_external_url': 'https://open.spotify.com/artist/46cVq2dwPgzPE3X1VR9TMj'},
#  {'artist_id': '48yQuRfvklyupKmridU1du',
#   'artist_name': 'Charita Utami',
#   'artist_external_url': 'https://open.spotify.com/artist/48yQuRfvklyupKmridU1du'},
#  {'artist_id': '4tuJ0bMpJh08umKkEXKUI5',
#   'artist_name': 'Gracie Abrams',
#   'artist_external_url': 'https://open.spotify.com/artist/4tuJ0bMpJh08umKkEXKUI5'},
#  {'artist_id': '2YZyLoL8N0Wb9xBt1NhZWg',
#   'artist_name': 'Kendrick Lamar',
#   'artist_external_url': 'https://open.spotify.com/artist/2YZyLoL8N0Wb9xBt1NhZWg'},
#  {'artist_id': '7tYKF4w9nC0nq9CsPZTHyP',
#   'artist_name': 'SZA',
#   'artist_external_url': 'https://open.spotify.com/artist/7tYKF4w9nC0nq9CsPZTHyP'},
#  {'artist_id': '1iCnM8foFssWlPRLfAbIwo',
#   'artist_name': 'Gigi Perez',
#   'artist_external_url': 'https://open.spotify.com/artist/1iCnM8foFssWlPRLfAbIwo'},
#  {'artist_id': '22wbnEMDvgVIAGdFeek6ET',
#   'artist_name': 'Benson Boone',
#   'artist_external_url': 'https://open.spotify.com/artist/22wbnEMDvgVIAGdFeek6ET'},
#  {'artist_id': '1oSPZhvZMIrWW5I41kPkkY',
#   'artist_name': 'Jimin',
#   'artist_external_url': 'https://open.spotify.com/artist/1oSPZhvZMIrWW5I41kPkkY'},
#  {'artist_id': '1HY2Jd0NmPuamShAr6KMms',
#   'artist_name': 'Lady Gaga',
#   'artist_external_url': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#  {'artist_id': '74KM79TiuVKeVCqs8QtB0B',
#   'artist_name': 'Sabrina Carpenter',
#   'artist_external_url': 'https://open.spotify.com/artist/74KM79TiuVKeVCqs8QtB0B'},
#  {'artist_id': '5RTLRtXjbXI2lSXc6jxlAz',
#   'artist_name': 'Ravyn Lenae',
#   'artist_external_url': 'https://open.spotify.com/artist/5RTLRtXjbXI2lSXc6jxlAz'},
#  {'artist_id': '67FB4n52MgexGQIG8s0yUH',
#   'artist_name': 'Lola Young',
#   'artist_external_url': 'https://open.spotify.com/artist/67FB4n52MgexGQIG8s0yUH'},
#  {'artist_id': '1Xyo4u8uXC1ZmMpatF05PJ',
#   'artist_name': 'The Weeknd',
#   'artist_external_url': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#  {'artist_id': '699OTQXzgjhIYAHMy9RyPD',
#   'artist_name': 'Playboi Carti',
#   'artist_external_url': 'https://open.spotify.com/artist/699OTQXzgjhIYAHMy9RyPD'},
#  {'artist_id': '4q3ewBCX7sLwd24euuV69X',
#   'artist_name': 'Bad Bunny',
#   'artist_external_url': 'https://open.spotify.com/artist/4q3ewBCX7sLwd24euuV69X'},
#  {'artist_id': '1Xyo4u8uXC1ZmMpatF05PJ',
#   'artist_name': 'The Weeknd',
#   'artist_external_url': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#  {'artist_id': '250b0Wlc5Vk0CoUsaCY84M',
#   'artist_name': 'JENNIE',
#   'artist_external_url': 'https://open.spotify.com/artist/250b0Wlc5Vk0CoUsaCY84M'},
#  {'artist_id': '1pBLC0qVRTB5zVMuteQ9jJ',
#   'artist_name': 'Lily-Rose Depp',
#   'artist_external_url': 'https://open.spotify.com/artist/1pBLC0qVRTB5zVMuteQ9jJ'},
#  {'artist_id': '2YZyLoL8N0Wb9xBt1NhZWg',
#   'artist_name': 'Kendrick Lamar',
#   'artist_external_url': 'https://open.spotify.com/artist/2YZyLoL8N0Wb9xBt1NhZWg'},
#  {'artist_id': '7tYKF4w9nC0nq9CsPZTHyP',
#   'artist_name': 'SZA',
#   'artist_external_url': 'https://open.spotify.com/artist/7tYKF4w9nC0nq9CsPZTHyP'},
#  {'artist_id': '33qOK5uJ8AR2xuQQAhHump',
#   'artist_name': 'Teddy Swims',
#   'artist_external_url': 'https://open.spotify.com/artist/33qOK5uJ8AR2xuQQAhHump'},
#  {'artist_id': '3ebS2RuCq8QeLyndUDmgB5',
#   'artist_name': 'WizTheMc',
#   'artist_external_url': 'https://open.spotify.com/artist/3ebS2RuCq8QeLyndUDmgB5'},
#  {'artist_id': '2OFij1ppCwYFCOTq7vzafi',
#   'artist_name': 'bees & honey',
#   'artist_external_url': 'https://open.spotify.com/artist/2OFij1ppCwYFCOTq7vzafi'},
#  {'artist_id': '4E2rKHVDssGJm2SCDOMMJB',
#   'artist_name': 'Doechii',
#   'artist_external_url': 'https://open.spotify.com/artist/4E2rKHVDssGJm2SCDOMMJB'},
#  {'artist_id': '3TVXtAsR1Inumwj472S9r4',
#   'artist_name': 'Drake',
#   'artist_external_url': 'https://open.spotify.com/artist/3TVXtAsR1Inumwj472S9r4'},
#  {'artist_id': '2sil8z5kiy4r76CRTXxBCA',
#   'artist_name': 'The Goo Goo Dolls',
#   'artist_external_url': 'https://open.spotify.com/artist/2sil8z5kiy4r76CRTXxBCA'},
#  {'artist_id': '4q3ewBCX7sLwd24euuV69X',
#   'artist_name': 'Bad Bunny',
#   'artist_external_url': 'https://open.spotify.com/artist/4q3ewBCX7sLwd24euuV69X'},
#  {'artist_id': '7GlBOeep6PqTfFi59PTUUN',
#   'artist_name': 'Chappell Roan',
#   'artist_external_url': 'https://open.spotify.com/artist/7GlBOeep6PqTfFi59PTUUN'},
#  {'artist_id': '7Ln80lUS6He07XvHI8qqHH',
#   'artist_name': 'Arctic Monkeys',
#   'artist_external_url': 'https://open.spotify.com/artist/7Ln80lUS6He07XvHI8qqHH'},
#  {'artist_id': '77SW9BnxLY8rJ0RciFqkHh',
#   'artist_name': 'The Neighbourhood',
#   'artist_external_url': 'https://open.spotify.com/artist/77SW9BnxLY8rJ0RciFqkHh'},
#  {'artist_id': '2kxP07DLgs4xlWz8YHlvfh',
#   'artist_name': 'NIKI',
#   'artist_external_url': 'https://open.spotify.com/artist/2kxP07DLgs4xlWz8YHlvfh'},
#  {'artist_id': '6ltzsmQQbmdoHHbLZ4ZN25',
#   'artist_name': 'Lord Huron',
#   'artist_external_url': 'https://open.spotify.com/artist/6ltzsmQQbmdoHHbLZ4ZN25'},
#  {'artist_id': '790FomKkXshlbRYZFtlgla',
#   'artist_name': 'KAROL G',
#   'artist_external_url': 'https://open.spotify.com/artist/790FomKkXshlbRYZFtlgla'},
#  {'artist_id': '0ys2OFYzWYB5hRDLCsBqxt',
#   'artist_name': 'Fuerza Regida',
#   'artist_external_url': 'https://open.spotify.com/artist/0ys2OFYzWYB5hRDLCsBqxt'},
#  {'artist_id': '2YZyLoL8N0Wb9xBt1NhZWg',
#   'artist_name': 'Kendrick Lamar',
#   'artist_external_url': 'https://open.spotify.com/artist/2YZyLoL8N0Wb9xBt1NhZWg'},
#  {'artist_id': '6pV5zH2LzjOUHaAvENdMMa',
#   'artist_name': 'Neton Vega',
#   'artist_external_url': 'https://open.spotify.com/artist/6pV5zH2LzjOUHaAvENdMMa'},
#  {'artist_id': '12GqGscKJx3aE4t07u7eVZ',
#   'artist_name': 'Peso Pluma',
#   'artist_external_url': 'https://open.spotify.com/artist/12GqGscKJx3aE4t07u7eVZ'},
#  {'artist_id': '5NGO30tJxFlKixkPSgXcFE',
#   'artist_name': 'The Police',
#   'artist_external_url': 'https://open.spotify.com/artist/5NGO30tJxFlKixkPSgXcFE'},
#  {'artist_id': '4q3ewBCX7sLwd24euuV69X',
#   'artist_name': 'Bad Bunny',
#   'artist_external_url': 'https://open.spotify.com/artist/4q3ewBCX7sLwd24euuV69X'},
#  {'artist_id': '4QFG9KrGWEbr6hNA58CAqE',
#   'artist_name': 'Alemán',
#   'artist_external_url': 'https://open.spotify.com/artist/4QFG9KrGWEbr6hNA58CAqE'},
#  {'artist_id': '6pV5zH2LzjOUHaAvENdMMa',
#   'artist_name': 'Neton Vega',
#   'artist_external_url': 'https://open.spotify.com/artist/6pV5zH2LzjOUHaAvENdMMa'},
#  {'artist_id': '2sSGPbdZJkaSE2AbcGOACx',
#   'artist_name': 'The Marías',
#   'artist_external_url': 'https://open.spotify.com/artist/2sSGPbdZJkaSE2AbcGOACx'},
#  {'artist_id': '3c0gDdb9lhnHGFtP4prQpn',
#   'artist_name': 'KATSEYE',
#   'artist_external_url': 'https://open.spotify.com/artist/3c0gDdb9lhnHGFtP4prQpn'},
#  {'artist_id': '45dkTj5sMRSjrmBSBeiHym',
#   'artist_name': 'Tate McRae',
#   'artist_external_url': 'https://open.spotify.com/artist/45dkTj5sMRSjrmBSBeiHym'},
#  {'artist_id': '7GlBOeep6PqTfFi59PTUUN',
#   'artist_name': 'Chappell Roan',
#   'artist_external_url': 'https://open.spotify.com/artist/7GlBOeep6PqTfFi59PTUUN'},
#  {'artist_id': '4q3ewBCX7sLwd24euuV69X',
#   'artist_name': 'Bad Bunny',
#   'artist_external_url': 'https://open.spotify.com/artist/4q3ewBCX7sLwd24euuV69X'},
#  {'artist_id': '3E12tRURRvPfHz0hAMCFYc',
#   'artist_name': 'Omar Courtz',
#   'artist_external_url': 'https://open.spotify.com/artist/3E12tRURRvPfHz0hAMCFYc'},
#  {'artist_id': '2YRyPiW98bpkARAS4B3OQP',
#   'artist_name': 'Dei V',
#   'artist_external_url': 'https://open.spotify.com/artist/2YRyPiW98bpkARAS4B3OQP'},
#  {'artist_id': '5SCDfg1YoEfI5gFtXqEWah',
#   'artist_name': 'ATLXS',
#   'artist_external_url': 'https://open.spotify.com/artist/5SCDfg1YoEfI5gFtXqEWah'},
#  {'artist_id': '0NlNru2YcUz6RbnpYGQz26',
#   'artist_name': 'Clave Especial',
#   'artist_external_url': 'https://open.spotify.com/artist/0NlNru2YcUz6RbnpYGQz26'},
#  {'artist_id': '0mA4dkNGiN4fqTBi2SLlAv',
#   'artist_name': 'Edgardo Nuñez',
#   'artist_external_url': 'https://open.spotify.com/artist/0mA4dkNGiN4fqTBi2SLlAv'},
#  {'artist_id': '4V8LLVI7PbaPR0K2TGSxFF',
#   'artist_name': 'Tyler, The Creator',
#   'artist_external_url': 'https://open.spotify.com/artist/4V8LLVI7PbaPR0K2TGSxFF'},
#  {'artist_id': '1U1el3k54VvEUzo3ybLPlM',
#   'artist_name': 'Kali Uchis',
#   'artist_external_url': 'https://open.spotify.com/artist/1U1el3k54VvEUzo3ybLPlM'},
#  {'artist_id': '4gzpq5DPGxSnKTe4SA8HAU',
#   'artist_name': 'Coldplay',
#   'artist_external_url': 'https://open.spotify.com/artist/4gzpq5DPGxSnKTe4SA8HAU'},
#  {'artist_id': '0ys2OFYzWYB5hRDLCsBqxt',
#   'artist_name': 'Fuerza Regida',
#   'artist_external_url': 'https://open.spotify.com/artist/0ys2OFYzWYB5hRDLCsBqxt'},
#  {'artist_id': '2FXC3k01G6Gw61bmprjgqS',
#   'artist_name': 'Hozier',
#   'artist_external_url': 'https://open.spotify.com/artist/2FXC3k01G6Gw61bmprjgqS'},
#  {'artist_id': '25uiPmTg16RbhZWAqwLBy5',
#   'artist_name': 'Charli xcx',
#   'artist_external_url': 'https://open.spotify.com/artist/25uiPmTg16RbhZWAqwLBy5'},
#  {'artist_id': '1HY2Jd0NmPuamShAr6KMms',
#   'artist_name': 'Lady Gaga',
#   'artist_external_url': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#  {'artist_id': '6zO1dZ40fTZ5hY9NnnRJSk',
#   'artist_name': 'yung kai',
#   'artist_external_url': 'https://open.spotify.com/artist/6zO1dZ40fTZ5hY9NnnRJSk'},
#  {'artist_id': '7Ln80lUS6He07XvHI8qqHH',
#   'artist_name': 'Arctic Monkeys',
#   'artist_external_url': 'https://open.spotify.com/artist/7Ln80lUS6He07XvHI8qqHH'},
#  {'artist_id': '0ys2OFYzWYB5hRDLCsBqxt',
#   'artist_name': 'Fuerza Regida',
#   'artist_external_url': 'https://open.spotify.com/artist/0ys2OFYzWYB5hRDLCsBqxt'},
#  {'artist_id': '6XkjpgcEsYab502Vr1bBeW',
#   'artist_name': 'Grupo Frontera',
#   'artist_external_url': 'https://open.spotify.com/artist/6XkjpgcEsYab502Vr1bBeW'},
#  {'artist_id': '1HY2Jd0NmPuamShAr6KMms',
#   'artist_name': 'Lady Gaga',
#   'artist_external_url': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#  {'artist_id': '74KM79TiuVKeVCqs8QtB0B',
#   'artist_name': 'Sabrina Carpenter',
#   'artist_external_url': 'https://open.spotify.com/artist/74KM79TiuVKeVCqs8QtB0B'},
#  {'artist_id': '6HaGTQPmzraVmaVxvz6EUc',
#   'artist_name': 'Jung Kook',
#   'artist_external_url': 'https://open.spotify.com/artist/6HaGTQPmzraVmaVxvz6EUc'},
#  {'artist_id': '3MdXrJWsbVzdn6fe5JYkSQ',
#   'artist_name': 'Latto',
#   'artist_external_url': 'https://open.spotify.com/artist/3MdXrJWsbVzdn6fe5JYkSQ'},
#  {'artist_id': '1ZMJSCQw8DIefcLb1FIpY0',
#   'artist_name': 'Los Dareyes De La Sierra',
#   'artist_external_url': 'https://open.spotify.com/artist/1ZMJSCQw8DIefcLb1FIpY0'},
#  {'artist_id': '5eumcnUkdmGvkvcsx1WFNG',
#   'artist_name': 'Tito Double P',
#   'artist_external_url': 'https://open.spotify.com/artist/5eumcnUkdmGvkvcsx1WFNG'},
#  {'artist_id': '4gzpq5DPGxSnKTe4SA8HAU',
#   'artist_name': 'Coldplay',
#   'artist_external_url': 'https://open.spotify.com/artist/4gzpq5DPGxSnKTe4SA8HAU'},
#  {'artist_id': '45dkTj5sMRSjrmBSBeiHym',
#   'artist_name': 'Tate McRae',
#   'artist_external_url': 'https://open.spotify.com/artist/45dkTj5sMRSjrmBSBeiHym'},
#  {'artist_id': '1mcTU81TzQhprhouKaTkpq',
#   'artist_name': 'Rauw Alejandro',
#   'artist_external_url': 'https://open.spotify.com/artist/1mcTU81TzQhprhouKaTkpq'},
#  {'artist_id': '4q3ewBCX7sLwd24euuV69X',
#   'artist_name': 'Bad Bunny',
#   'artist_external_url': 'https://open.spotify.com/artist/4q3ewBCX7sLwd24euuV69X'},
#  {'artist_id': '7CvTknweLr9feJtRGrpDBy',
#   'artist_name': 'FloyyMenor',
#   'artist_external_url': 'https://open.spotify.com/artist/7CvTknweLr9feJtRGrpDBy'},
#  {'artist_id': '1Yj5Xey7kTwvZla8sqdsdE',
#   'artist_name': 'Cris Mj',
#   'artist_external_url': 'https://open.spotify.com/artist/1Yj5Xey7kTwvZla8sqdsdE'},
#  {'artist_id': '3DeOmVSmpv7WknXoo1OS8p',
#   'artist_name': 'Alleh',
#   'artist_external_url': 'https://open.spotify.com/artist/3DeOmVSmpv7WknXoo1OS8p'},
#  {'artist_id': '4eq1q0o9XPyNq9RG3fNDD1',
#   'artist_name': 'Yorghaki',
#   'artist_external_url': 'https://open.spotify.com/artist/4eq1q0o9XPyNq9RG3fNDD1'},
#  {'artist_id': '4Z8W4fKeB5YxbusRsdQVPb',
#   'artist_name': 'Radiohead',
#   'artist_external_url': 'https://open.spotify.com/artist/4Z8W4fKeB5YxbusRsdQVPb'},
#  {'artist_id': '33qOK5uJ8AR2xuQQAhHump',
#   'artist_name': 'Teddy Swims',
#   'artist_external_url': 'https://open.spotify.com/artist/33qOK5uJ8AR2xuQQAhHump'},
#  {'artist_id': '0NlNru2YcUz6RbnpYGQz26',
#   'artist_name': 'Clave Especial',
#   'artist_external_url': 'https://open.spotify.com/artist/0NlNru2YcUz6RbnpYGQz26'},
#  {'artist_id': '0ys2OFYzWYB5hRDLCsBqxt',
#   'artist_name': 'Fuerza Regida',
#   'artist_external_url': 'https://open.spotify.com/artist/0ys2OFYzWYB5hRDLCsBqxt'},
#  {'artist_id': '22wbnEMDvgVIAGdFeek6ET',
#   'artist_name': 'Benson Boone',
#   'artist_external_url': 'https://open.spotify.com/artist/22wbnEMDvgVIAGdFeek6ET'},
#  {'artist_id': '61nn6nOoLWjVC1ER2qFAvN',
#   'artist_name': 'Cup of Joe',
#   'artist_external_url': 'https://open.spotify.com/artist/61nn6nOoLWjVC1ER2qFAvN'},
#  {'artist_id': '5bQ3wFgekuIMIcWJuxkqLK',
#   'artist_name': 'Chrystal',
#   'artist_external_url': 'https://open.spotify.com/artist/5bQ3wFgekuIMIcWJuxkqLK'},
#  {'artist_id': '1uRVM0wBdtyEuU582EeKJM',
#   'artist_name': 'NOTION',
#   'artist_external_url': 'https://open.spotify.com/artist/1uRVM0wBdtyEuU582EeKJM'},
#  {'artist_id': '1Xyo4u8uXC1ZmMpatF05PJ',
#   'artist_name': 'The Weeknd',
#   'artist_external_url': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#  {'artist_id': '4tZwfgrHOc3mvqYlEYSvVi',
#   'artist_name': 'Daft Punk',
#   'artist_external_url': 'https://open.spotify.com/artist/4tZwfgrHOc3mvqYlEYSvVi'},
#  {'artist_id': '3y2cIKLjiOlp1Np37WiUdH',
#   'artist_name': 'Shaboozey',
#   'artist_external_url': 'https://open.spotify.com/artist/3y2cIKLjiOlp1Np37WiUdH'},
#  {'artist_id': '66CXWjxzNUsdJxJ2JdwvnR',
#   'artist_name': 'Ariana Grande',
#   'artist_external_url': 'https://open.spotify.com/artist/66CXWjxzNUsdJxJ2JdwvnR'},
#  {'artist_id': '3bO19AOone0ubCsfDXDtYt',
#   'artist_name': 'Myles Smith',
#   'artist_external_url': 'https://open.spotify.com/artist/3bO19AOone0ubCsfDXDtYt'},
#  {'artist_id': '2YZyLoL8N0Wb9xBt1NhZWg',
#   'artist_name': 'Kendrick Lamar',
#   'artist_external_url': 'https://open.spotify.com/artist/2YZyLoL8N0Wb9xBt1NhZWg'},
#  {'artist_id': '1jiZvw42D4oquLl24x2VWV',
#   'artist_name': 'Lefty Gunplay',
#   'artist_external_url': 'https://open.spotify.com/artist/1jiZvw42D4oquLl24x2VWV'},
#  {'artist_id': '5LcNPa8f8bRmZqELgoRFkN',
#   'artist_name': 'Raim Laode',
#   'artist_external_url': 'https://open.spotify.com/artist/5LcNPa8f8bRmZqELgoRFkN'},
#  {'artist_id': '5y8tKLUfMvliMe8IKamR32',
#   'artist_name': 'd4vd',
#   'artist_external_url': 'https://open.spotify.com/artist/5y8tKLUfMvliMe8IKamR32'},
#  {'artist_id': '6eUKZXaKkcviH0Ku9w2n3V',
#   'artist_name': 'Ed Sheeran',
#   'artist_external_url': 'https://open.spotify.com/artist/6eUKZXaKkcviH0Ku9w2n3V'},
#  {'artist_id': '22wbnEMDvgVIAGdFeek6ET',
#   'artist_name': 'Benson Boone',
#   'artist_external_url': 'https://open.spotify.com/artist/22wbnEMDvgVIAGdFeek6ET'},
#  {'artist_id': '6XyY86QOPPrYVGvF9ch6wz',
#   'artist_name': 'Linkin Park',
#   'artist_external_url': 'https://open.spotify.com/artist/6XyY86QOPPrYVGvF9ch6wz'},
#  {'artist_id': '4V8LLVI7PbaPR0K2TGSxFF',
#   'artist_name': 'Tyler, The Creator',
#   'artist_external_url': 'https://open.spotify.com/artist/4V8LLVI7PbaPR0K2TGSxFF'},
#  {'artist_id': '67FB4n52MgexGQIG8s0yUH',
#   'artist_name': 'Lola Young',
#   'artist_external_url': 'https://open.spotify.com/artist/67FB4n52MgexGQIG8s0yUH'},
#  {'artist_id': '1HY2Jd0NmPuamShAr6KMms',
#   'artist_name': 'Lady Gaga',
#   'artist_external_url': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#  {'artist_id': '4VIvfOurcf0vuLRxLkGnIG',
#   'artist_name': 'Bradley Cooper',
#   'artist_external_url': 'https://open.spotify.com/artist/4VIvfOurcf0vuLRxLkGnIG'},
#  {'artist_id': '6eUKZXaKkcviH0Ku9w2n3V',
#   'artist_name': 'Ed Sheeran',
#   'artist_external_url': 'https://open.spotify.com/artist/6eUKZXaKkcviH0Ku9w2n3V'},
#  {'artist_id': '6VcsqZOR5AtEOGeAtmutCZ',
#   'artist_name': 'Esau Ortiz',
#   'artist_external_url': 'https://open.spotify.com/artist/6VcsqZOR5AtEOGeAtmutCZ'},
#  {'artist_id': '3Y9A8EQQtWU8RStiTlzErv',
#   'artist_name': 'Jombriel',
#   'artist_external_url': 'https://open.spotify.com/artist/3Y9A8EQQtWU8RStiTlzErv'},
#  {'artist_id': '6ndLrsgT3MV5CNxIrW71fw',
#   'artist_name': 'DFZM',
#   'artist_external_url': 'https://open.spotify.com/artist/6ndLrsgT3MV5CNxIrW71fw'},
#  {'artist_id': '2wnVvfvSkFJbtOinte4sC3',
#   'artist_name': 'Jøtta',
#   'artist_external_url': 'https://open.spotify.com/artist/2wnVvfvSkFJbtOinte4sC3'},
#  {'artist_id': '1vyhD5VmyZ7KMfW5gqLgo5',
#   'artist_name': 'J Balvin',
#   'artist_external_url': 'https://open.spotify.com/artist/1vyhD5VmyZ7KMfW5gqLgo5'},
#  {'artist_id': '4q3ewBCX7sLwd24euuV69X',
#   'artist_name': 'Bad Bunny',
#   'artist_external_url': 'https://open.spotify.com/artist/4q3ewBCX7sLwd24euuV69X'},
#  {'artist_id': '5p9HO3XC5P3BLxJs5Mtrhm',
#   'artist_name': 'Djo',
#   'artist_external_url': 'https://open.spotify.com/artist/5p9HO3XC5P3BLxJs5Mtrhm'},
#  {'artist_id': '6pV5zH2LzjOUHaAvENdMMa',
#   'artist_name': 'Neton Vega',
#   'artist_external_url': 'https://open.spotify.com/artist/6pV5zH2LzjOUHaAvENdMMa'},
#  {'artist_id': '4Ga1P7PMIsmqEZqhYZQgDo',
#   'artist_name': 'Lil Tecca',
#   'artist_external_url': 'https://open.spotify.com/artist/4Ga1P7PMIsmqEZqhYZQgDo'},
#  {'artist_id': '1QAJqy2dA3ihHBFIHRphZj',
#   'artist_name': 'Cigarettes After Sex',
#   'artist_external_url': 'https://open.spotify.com/artist/1QAJqy2dA3ihHBFIHRphZj'},
#  {'artist_id': '2txHhyCwHjUEpJjWrEyqyX',
#   'artist_name': 'Tom Odell',
#   'artist_external_url': 'https://open.spotify.com/artist/2txHhyCwHjUEpJjWrEyqyX'},
#  {'artist_id': '2hVWBpjLW4Q7fboYz2pVYK',
#   'artist_name': 'MOLIY',
#   'artist_external_url': 'https://open.spotify.com/artist/2hVWBpjLW4Q7fboYz2pVYK'},
#  {'artist_id': '2myuqB0gKAo75dE2eSWgzt',
#   'artist_name': 'Silent Addy',
#   'artist_external_url': 'https://open.spotify.com/artist/2myuqB0gKAo75dE2eSWgzt'},
#  {'artist_id': '5FkUhnHQ0KC63549LHHtst',
#   'artist_name': 'Skillibeng',
#   'artist_external_url': 'https://open.spotify.com/artist/5FkUhnHQ0KC63549LHHtst'},
#  {'artist_id': '1OFOShsIbhy1l5x73yuVyB',
#   'artist_name': 'Shenseea',
#   'artist_external_url': 'https://open.spotify.com/artist/1OFOShsIbhy1l5x73yuVyB'},
#  {'artist_id': '74KM79TiuVKeVCqs8QtB0B',
#   'artist_name': 'Sabrina Carpenter',
#   'artist_external_url': 'https://open.spotify.com/artist/74KM79TiuVKeVCqs8QtB0B'},
#  {'artist_id': '246dkjvS1zLTtiykXe5h60',
#   'artist_name': 'Post Malone',
#   'artist_external_url': 'https://open.spotify.com/artist/246dkjvS1zLTtiykXe5h60'},
#  {'artist_id': '4oUHIQIBe0LHzYfvXNW4QM',
#   'artist_name': 'Morgan Wallen',
#   'artist_external_url': 'https://open.spotify.com/artist/4oUHIQIBe0LHzYfvXNW4QM'},
#  {'artist_id': '4q3ewBCX7sLwd24euuV69X',
#   'artist_name': 'Bad Bunny',
#   'artist_external_url': 'https://open.spotify.com/artist/4q3ewBCX7sLwd24euuV69X'},
#  {'artist_id': '5Pwc4xIPtQLFEnJriah9YJ',
#   'artist_name': 'OneRepublic',
#   'artist_external_url': 'https://open.spotify.com/artist/5Pwc4xIPtQLFEnJriah9YJ'}]

# %%
# list of songs
song_list = []
for row in data['items']:
    song_dict = {
        "song_id": row['track']['id'],
        "song_name": row['track']['name'],
        "song_popularity": row['track']['popularity'],
        "song_url": row['track']['external_urls']['spotify'],
        "song_duration": row['track']['duration_ms'],
        "song_added": row['added_at'],
        "album_id": row['track']['album']['id'],
        "artist_id": row['track']['album']['artists'][0]['id'],
    }
    song_list.append(song_dict)

song_list
# Out:
# [{'song_id': '2RkZ5LkEzeHGRsmDqKwmaJ',
#   'song_name': 'Ordinary',
#   'song_popularity': 92,
#   'song_url': 'https://open.spotify.com/track/2RkZ5LkEzeHGRsmDqKwmaJ',
#   'song_duration': 186964,
#   'song_added': '2025-04-01T23:38:28Z',
#   'album_id': '1eCGY9WJpYgtaFh1Lk2KNo',
#   'artist_id': '0fTSzq9jAh4c36UVb4V7CB'},
#  {'song_id': '7so0lgd0zP2Sbgs2d7a1SZ',
#   'song_name': 'Die With A Smile',
#   'song_popularity': 91,
#   'song_url': 'https://open.spotify.com/track/7so0lgd0zP2Sbgs2d7a1SZ',
#   'song_duration': 251667,
#   'song_added': '2025-03-11T23:15:56Z',
#   'album_id': '2MHUaRi9OCyTN02SoyRRBJ',
#   'artist_id': '1HY2Jd0NmPuamShAr6KMms'},
#  {'song_id': '6dOtVTDdiauQNBQEDOtlAB',
#   'song_name': 'BIRDS OF A FEATHER',
#   'song_popularity': 100,
#   'song_url': 'https://open.spotify.com/track/6dOtVTDdiauQNBQEDOtlAB',
#   'song_duration': 210373,
#   'song_added': '2025-01-02T15:25:39Z',
#   'album_id': '7aJuG4TFXa2hmE4z1yxc3n',
#   'artist_id': '6qqNVTkY8uBg9cP3Jd7DAH'},
#  {'song_id': '4wJ5Qq0jBN4ajy7ouZIV1c',
#   'song_name': 'APT.',
#   'song_popularity': 91,
#   'song_url': 'https://open.spotify.com/track/4wJ5Qq0jBN4ajy7ouZIV1c',
#   'song_duration': 169917,
#   'song_added': '2025-01-02T15:25:39Z',
#   'album_id': '7kFyd5oyJdVX2pIi6P4iHE',
#   'artist_id': '3eVa5w3URK5duf6eyVDbu9'},
#  {'song_id': '3sK8wGT43QFpWrvNQsrQya',
#   'song_name': 'DtMF',
#   'song_popularity': 97,
#   'song_url': 'https://open.spotify.com/track/3sK8wGT43QFpWrvNQsrQya',
#   'song_duration': 237117,
#   'song_added': '2025-01-08T02:14:55Z',
#   'album_id': '5K79FLRUCSysQnVESLcTdb',
#   'artist_id': '4q3ewBCX7sLwd24euuV69X'},
#  {'song_id': '0FTmksd2dxiE5e3rWyJXs6',
#   'song_name': 'back to friends',
#   'song_popularity': 95,
#   'song_url': 'https://open.spotify.com/track/0FTmksd2dxiE5e3rWyJXs6',
#   'song_duration': 199032,
#   'song_added': '2025-03-25T21:30:25Z',
#   'album_id': '0QLILSOq1IqAqx62drmv4E',
#   'artist_id': '4G9NDjRyZFDlJKMRL8hx3S'},
#  {'song_id': '6iOndD4OFo7GkaDypWQIou',
#   'song_name': 'La Plena - W Sound 05',
#   'song_popularity': 94,
#   'song_url': 'https://open.spotify.com/track/6iOndD4OFo7GkaDypWQIou',
#   'song_duration': 150001,
#   'song_added': '2025-03-05T04:40:18Z',
#   'album_id': '4Xdo78uvvt1P7rWRX8TOPt',
#   'artist_id': '5uwa6tAMMfNbBFIHiI6NV4'},
#  {'song_id': '4AajxCEwGEsmHmT4H1TwjY',
#   'song_name': 'undressed',
#   'song_popularity': 93,
#   'song_url': 'https://open.spotify.com/track/4AajxCEwGEsmHmT4H1TwjY',
#   'song_duration': 182088,
#   'song_added': '2025-04-01T23:43:19Z',
#   'album_id': '19m6pwPmwNFSPV7wtHtg7D',
#   'artist_id': '4G9NDjRyZFDlJKMRL8hx3S'},
#  {'song_id': '2lTm559tuIvatlT1u0JYG2',
#   'song_name': 'BAILE INoLVIDABLE',
#   'song_popularity': 96,
#   'song_url': 'https://open.spotify.com/track/2lTm559tuIvatlT1u0JYG2',
#   'song_duration': 367725,
#   'song_added': '2025-01-08T02:14:55Z',
#   'album_id': '5K79FLRUCSysQnVESLcTdb',
#   'artist_id': '4q3ewBCX7sLwd24euuV69X'},
#  {'song_id': '0fK7ie6XwGxQTIkpFoWkd1',
#   'song_name': 'like JENNIE',
#   'song_popularity': 96,
#   'song_url': 'https://open.spotify.com/track/0fK7ie6XwGxQTIkpFoWkd1',
#   'song_duration': 123517,
#   'song_added': '2025-03-11T23:16:28Z',
#   'album_id': '1vWMw6pu3err6qqZzI3RhH',
#   'artist_id': '250b0Wlc5Vk0CoUsaCY84M'},
#  {'song_id': '3QaPy1KgI7nu9FJEQUgn6h',
#   'song_name': 'WILDFLOWER',
#   'song_popularity': 96,
#   'song_url': 'https://open.spotify.com/track/3QaPy1KgI7nu9FJEQUgn6h',
#   'song_duration': 261466,
#   'song_added': '2025-01-02T15:25:39Z',
#   'album_id': '7aJuG4TFXa2hmE4z1yxc3n',
#   'artist_id': '6qqNVTkY8uBg9cP3Jd7DAH'},
#  {'song_id': '4e6TmHCC4PRUj75knNplNP',
#   'song_name': 'Mangu',
#   'song_popularity': 82,
#   'song_url': 'https://open.spotify.com/track/4e6TmHCC4PRUj75knNplNP',
#   'song_duration': 261048,
#   'song_added': '2025-04-22T22:38:22Z',
#   'album_id': '6XVW3zoK1nmskW7drvHy9h',
#   'artist_id': '46cVq2dwPgzPE3X1VR9TMj'},
#  {'song_id': '7ne4VBA60CxGM75vw0EYad',
#   'song_name': 'That’s So True',
#   'song_popularity': 97,
#   'song_url': 'https://open.spotify.com/track/7ne4VBA60CxGM75vw0EYad',
#   'song_duration': 166300,
#   'song_added': '2025-01-02T15:25:39Z',
#   'album_id': '0hBRqPYPXhr1RkTDG3n4Mk',
#   'artist_id': '4tuJ0bMpJh08umKkEXKUI5'},
#  {'song_id': '45J4avUb9Ni0bnETYaYFVJ',
#   'song_name': 'luther (with sza)',
#   'song_popularity': 92,
#   'song_url': 'https://open.spotify.com/track/45J4avUb9Ni0bnETYaYFVJ',
#   'song_duration': 177598,
#   'song_added': '2025-01-02T15:25:39Z',
#   'album_id': '0hvT3yIEysuuvkK73vgdcW',
#   'artist_id': '2YZyLoL8N0Wb9xBt1NhZWg'},
#  {'song_id': '0UYnhUfnUj5adChuAXvLUB',
#   'song_name': 'Sailor Song',
#   'song_popularity': 18,
#   'song_url': 'https://open.spotify.com/track/0UYnhUfnUj5adChuAXvLUB',
#   'song_duration': 211978,
#   'song_added': '2025-01-02T15:25:39Z',
#   'album_id': '4DWrYvfGXRE8ko5ZxlIpit',
#   'artist_id': '1iCnM8foFssWlPRLfAbIwo'},
#  {'song_id': '3xkHsmpQCBMytMJNiDf3Ii',
#   'song_name': 'Beautiful Things',
#   'song_popularity': 93,
#   'song_url': 'https://open.spotify.com/track/3xkHsmpQCBMytMJNiDf3Ii',
#   'song_duration': 180304,
#   'song_added': '2025-01-02T15:25:39Z',
#   'album_id': '168CdR21lfn0TTyw1Pkdcm',
#   'artist_id': '22wbnEMDvgVIAGdFeek6ET'},
#  {'song_id': '7tI8dRuH2Yc6RuoTjxo4dU',
#   'song_name': 'Who',
#   'song_popularity': 90,
#   'song_url': 'https://open.spotify.com/track/7tI8dRuH2Yc6RuoTjxo4dU',
#   'song_duration': 170887,
#   'song_added': '2025-01-02T15:25:39Z',
#   'album_id': '15XcLhiVMlSOipUddTNDnr',
#   'artist_id': '1oSPZhvZMIrWW5I41kPkkY'},
#  {'song_id': '2LHNTC9QZxsL3nWpt8iaSR',
#   'song_name': 'Abracadabra',
#   'song_popularity': 89,
#   'song_url': 'https://open.spotify.com/track/2LHNTC9QZxsL3nWpt8iaSR',
#   'song_duration': 223398,
#   'song_added': '2025-03-11T23:16:15Z',
#   'album_id': '2MHUaRi9OCyTN02SoyRRBJ',
#   'artist_id': '1HY2Jd0NmPuamShAr6KMms'},
#  {'song_id': '2HRqTpkrJO5ggZyyK6NPWz',
#   'song_name': 'Espresso',
#   'song_popularity': 91,
#   'song_url': 'https://open.spotify.com/track/2HRqTpkrJO5ggZyyK6NPWz',
#   'song_duration': 175459,
#   'song_added': '2025-01-02T15:25:39Z',
#   'album_id': '3iPSVi54hsacKKl1xIR2eH',
#   'artist_id': '74KM79TiuVKeVCqs8QtB0B'},
#  {'song_id': '4WFgvKVfEhb3IUAFGrutTR',
#   'song_name': 'Love Me Not',
#   'song_popularity': 88,
#   'song_url': 'https://open.spotify.com/track/4WFgvKVfEhb3IUAFGrutTR',
#   'song_duration': 213466,
#   'song_added': '2025-03-25T21:36:43Z',
#   'album_id': '1uE3dRPe3SrGdNhd1nWlSa',
#   'artist_id': '5RTLRtXjbXI2lSXc6jxlAz'},
#  {'song_id': '35ISBknsCeZQtq66xABI9g',
#   'song_name': 'Messy',
#   'song_popularity': 90,
#   'song_url': 'https://open.spotify.com/track/35ISBknsCeZQtq66xABI9g',
#   'song_duration': 284066,
#   'song_added': '2025-01-02T15:25:39Z',
#   'album_id': '3uTpTaMOynCYKV5AtgeO2U',
#   'artist_id': '67FB4n52MgexGQIG8s0yUH'},
#  {'song_id': '0FIDCNYYjNvPVimz5icugS',
#   'song_name': 'Timeless (feat Playboi Carti)',
#   'song_popularity': 95,
#   'song_url': 'https://open.spotify.com/track/0FIDCNYYjNvPVimz5icugS',
#   'song_duration': 256000,
#   'song_added': '2025-02-06T05:14:50Z',
#   'album_id': '3OxfaVgvTxUTy7276t7SPU',
#   'artist_id': '1Xyo4u8uXC1ZmMpatF05PJ'},
#  {'song_id': '6J5kc12BW5HuP3d7C3vvx8',
#   'song_name': 'EoO',
#   'song_popularity': 94,
#   'song_url': 'https://open.spotify.com/track/6J5kc12BW5HuP3d7C3vvx8',
#   'song_duration': 204768,
#   'song_added': '2025-01-08T02:14:55Z',
#   'album_id': '5K79FLRUCSysQnVESLcTdb',
#   'artist_id': '4q3ewBCX7sLwd24euuV69X'},
#  {'song_id': '7CyPwkp0oE8Ro9Dd5CUDjW',
#   'song_name': 'One Of The Girls (with JENNIE, Lily Rose Depp)',
#   'song_popularity': 94,
#   'song_url': 'https://open.spotify.com/track/7CyPwkp0oE8Ro9Dd5CUDjW',
#   'song_duration': 244684,
#   'song_added': '2025-01-02T15:25:39Z',
#   'album_id': '7tzVd1fwkxsorytCBjEJkU',
#   'artist_id': '1Xyo4u8uXC1ZmMpatF05PJ'},
#  {'song_id': '3GCdLUSnKSMJhs4Tj6CV3s',
#   'song_name': 'All The Stars (with SZA)',
#   'song_popularity': 95,
#   'song_url': 'https://open.spotify.com/track/3GCdLUSnKSMJhs4Tj6CV3s',
#   'song_duration': 232186,
#   'song_added': '2025-01-02T15:25:39Z',
#   'album_id': '3pLdWdkj83EYfDN6H2N8MR',
#   'artist_id': '2YZyLoL8N0Wb9xBt1NhZWg'},
#  {'song_id': '17phhZDn6oGtzMe56NuWvj',
#   'song_name': 'Lose Control',
#   'song_popularity': 92,
#   'song_url': 'https://open.spotify.com/track/17phhZDn6oGtzMe56NuWvj',
#   'song_duration': 210688,
#   'song_added': '2025-01-02T15:25:39Z',
#   'album_id': '7nacKlk586eLRBSIsrk9DB',
#   'artist_id': '33qOK5uJ8AR2xuQQAhHump'},
#  {'song_id': '5ITV0zqzjOYfFWpW0xBmRa',
#   'song_name': 'Show Me Love',
#   'song_popularity': 94,
#   'song_url': 'https://open.spotify.com/track/5ITV0zqzjOYfFWpW0xBmRa',
#   'song_duration': 176965,
#   'song_added': '2025-03-11T23:27:43Z',
#   'album_id': '4gyYKUIAOEcP50RM1Sjzj6',
#   'artist_id': '3ebS2RuCq8QeLyndUDmgB5'},
#  {'song_id': '3LPLRNr58Z9Pn0clnEtkXb',
#   'song_name': 'Anxiety',
#   'song_popularity': 87,
#   'song_url': 'https://open.spotify.com/track/3LPLRNr58Z9Pn0clnEtkXb',
#   'song_duration': 249302,
#   'song_added': '2025-03-18T20:15:17Z',
#   'album_id': '5yPu6XkHu8DAGmV6YkXYZq',
#   'artist_id': '4E2rKHVDssGJm2SCDOMMJB'},
#  {'song_id': '2u9S9JJ6hTZS3Vf22HOZKg',
#   'song_name': 'NOKIA',
#   'song_popularity': 94,
#   'song_url': 'https://open.spotify.com/track/2u9S9JJ6hTZS3Vf22HOZKg',
#   'song_duration': 241023,
#   'song_added': '2025-02-19T18:09:58Z',
#   'album_id': '6Rl6YoCarF2GHPSQmmFjuR',
#   'artist_id': '2HPaUgqeutzr3jx5a9WyDV'},
#  {'song_id': '6Qyc6fS4DsZjB2mRW9DsQs',
#   'song_name': 'Iris',
#   'song_popularity': 93,
#   'song_url': 'https://open.spotify.com/track/6Qyc6fS4DsZjB2mRW9DsQs',
#   'song_duration': 289533,
#   'song_added': '2025-01-02T15:25:39Z',
#   'album_id': '4UMjBXcRqIgMZ1XumU2x5T',
#   'artist_id': '2sil8z5kiy4r76CRTXxBCA'},
#  {'song_id': '5TFD2bmFKGhoCRbX61nXY5',
#   'song_name': 'NUEVAYoL',
#   'song_popularity': 94,
#   'song_url': 'https://open.spotify.com/track/5TFD2bmFKGhoCRbX61nXY5',
#   'song_duration': 183685,
#   'song_added': '2025-01-08T02:14:55Z',
#   'album_id': '5K79FLRUCSysQnVESLcTdb',
#   'artist_id': '4q3ewBCX7sLwd24euuV69X'},
#  {'song_id': '0WbMK4wrZ1wFSty9F7FCgu',
#   'song_name': 'Good Luck, Babe!',
#   'song_popularity': 95,
#   'song_url': 'https://open.spotify.com/track/0WbMK4wrZ1wFSty9F7FCgu',
#   'song_duration': 218423,
#   'song_added': '2025-01-02T15:25:39Z',
#   'album_id': '1WAjjRMfZjEXtB0lQrAw6Q',
#   'artist_id': '7GlBOeep6PqTfFi59PTUUN'},
#  {'song_id': '5XeFesFbtLpXzIVDNQP22n',
#   'song_name': 'I Wanna Be Yours',
#   'song_popularity': 94,
#   'song_url': 'https://open.spotify.com/track/5XeFesFbtLpXzIVDNQP22n',
#   'song_duration': 183956,
#   'song_added': '2025-01-02T15:25:39Z',
#   'album_id': '78bpIziExqiI9qztvNFlQu',
#   'artist_id': '7Ln80lUS6He07XvHI8qqHH'},
#  {'song_id': '2QjOHCTQ1Jl3zawyYOpxh6',
#   'song_name': 'Sweater Weather',
#   'song_popularity': 93,
#   'song_url': 'https://open.spotify.com/track/2QjOHCTQ1Jl3zawyYOpxh6',
#   'song_duration': 240400,
#   'song_added': '2025-01-02T15:25:39Z',
#   'album_id': '4xkM0BwLM9H2IUcbYzpcBI',
#   'artist_id': '77SW9BnxLY8rJ0RciFqkHh'},
#  {'song_id': '1UPB5rYJ0bzn6mNSoAHrZC',
#   'song_name': "You'll Be in My Heart",
#   'song_popularity': 92,
#   'song_url': 'https://open.spotify.com/track/1UPB5rYJ0bzn6mNSoAHrZC',
#   'song_duration': 241776,
#   'song_added': '2025-03-25T21:55:57Z',
#   'album_id': '7GZpa8xckIRPFIbT49B4zZ',
#   'artist_id': '2kxP07DLgs4xlWz8YHlvfh'},
#  {'song_id': '3hRV0jL3vUpRrcy398teAU',
#   'song_name': 'The Night We Met',
#   'song_popularity': 91,
#   'song_url': 'https://open.spotify.com/track/3hRV0jL3vUpRrcy398teAU',
#   'song_duration': 208211,
#   'song_added': '2025-01-02T15:25:39Z',
#   'album_id': '4sD1qg4jwTZR4mvR4Iflk5',
#   'artist_id': '6ltzsmQQbmdoHHbLZ4ZN25'},
#  {'song_id': '6WatFBLVB0x077xWeoVc2k',
#   'song_name': 'Si Antes Te Hubiera Conocido',
#   'song_popularity': 94,
#   'song_url': 'https://open.spotify.com/track/6WatFBLVB0x077xWeoVc2k',
#   'song_duration': 195824,
#   'song_added': '2025-01-02T15:25:39Z',
#   'album_id': '5ylbxH7EqpsmHZCRuiYewS',
#   'artist_id': '790FomKkXshlbRYZFtlgla'},
#  {'song_id': '77pDO4WZPIdkwFve0iHWnb',
#   'song_name': 'Por Esos Ojos',
#   'song_popularity': 79,
#   'song_url': 'https://open.spotify.com/track/77pDO4WZPIdkwFve0iHWnb',
#   'song_duration': 188064,
#   'song_added': '2025-05-06T23:21:22Z',
#   'album_id': '1JpJzuM4uncCfCimVozkmy',
#   'artist_id': '0ys2OFYzWYB5hRDLCsBqxt'},
#  {'song_id': '6AI3ezQ4o3HUoP6Dhudph3',
#   'song_name': 'Not Like Us',
#   'song_popularity': 95,
#   'song_url': 'https://open.spotify.com/track/6AI3ezQ4o3HUoP6Dhudph3',
#   'song_duration': 274192,
#   'song_added': '2025-01-02T15:25:39Z',
#   'album_id': '5JjnoGJyOxfSZUZtk2rRwZ',
#   'artist_id': '2YZyLoL8N0Wb9xBt1NhZWg'},
#  {'song_id': '4oB8Xd7gMlUEtWoD8bmCXW',
#   'song_name': 'Morena',
#   'song_popularity': 93,
#   'song_url': 'https://open.spotify.com/track/4oB8Xd7gMlUEtWoD8bmCXW',
#   'song_duration': 193728,
#   'song_added': '2025-02-19T18:32:54Z',
#   'album_id': '338NDGMHtB4t5mp8RhMnh3',
#   'artist_id': '6pV5zH2LzjOUHaAvENdMMa'},
#  {'song_id': '1JSTJqkT5qHq8MDJnJbRE1',
#   'song_name': 'Every Breath You Take',
#   'song_popularity': 92,
#   'song_url': 'https://open.spotify.com/track/1JSTJqkT5qHq8MDJnJbRE1',
#   'song_duration': 253920,
#   'song_added': '2025-01-02T15:25:39Z',
#   'album_id': '5W9OT0a5iZlBr83a9WMKFY',
#   'artist_id': '5NGO30tJxFlKixkPSgXcFE'},
#  {'song_id': '59D4DOkspUbWyMmbAPQkxZ',
#   'song_name': 'VOY A LLeVARTE PA PR',
#   'song_popularity': 93,
#   'song_url': 'https://open.spotify.com/track/59D4DOkspUbWyMmbAPQkxZ',
#   'song_duration': 156364,
#   'song_added': '2025-01-08T02:14:55Z',
#   'album_id': '5K79FLRUCSysQnVESLcTdb',
#   'artist_id': '4q3ewBCX7sLwd24euuV69X'},
#  {'song_id': '2JPctdUgvkQSpnUdfROxvY',
#   'song_name': 'Te Quería Ver',
#   'song_popularity': 68,
#   'song_url': 'https://open.spotify.com/track/2JPctdUgvkQSpnUdfROxvY',
#   'song_duration': 176129,
#   'song_added': '2025-05-13T21:31:11Z',
#   'album_id': '2YgSHCBlOE0ZamNGQBg19Q',
#   'artist_id': '4QFG9KrGWEbr6hNA58CAqE'},
#  {'song_id': '3siwsiaEoU4Kuuc9WKMUy5',
#   'song_name': 'No One Noticed',
#   'song_popularity': 93,
#   'song_url': 'https://open.spotify.com/track/3siwsiaEoU4Kuuc9WKMUy5',
#   'song_duration': 236906,
#   'song_added': '2025-01-02T15:25:39Z',
#   'album_id': '03guxdOi12XJbnvxvxbpwG',
#   'artist_id': '2sSGPbdZJkaSE2AbcGOACx'},
#  {'song_id': '1j15Ar0qGDzIR0v3CQv3JL',
#   'song_name': 'Gnarly',
#   'song_popularity': 85,
#   'song_url': 'https://open.spotify.com/track/1j15Ar0qGDzIR0v3CQv3JL',
#   'song_duration': 137316,
#   'song_added': '2025-05-06T23:23:04Z',
#   'album_id': '25oD4E4cwmG7SCQIoF3ez5',
#   'artist_id': '3c0gDdb9lhnHGFtP4prQpn'},
#  {'song_id': '3pjpG96WxzRnxNFxZC56vV',
#   'song_name': 'Sports car',
#   'song_popularity': 77,
#   'song_url': 'https://open.spotify.com/track/3pjpG96WxzRnxNFxZC56vV',
#   'song_duration': 165045,
#   'song_added': '2025-02-25T23:32:39Z',
#   'album_id': '6KaEpgeZQF6ZVVAmSoZUrb',
#   'artist_id': '45dkTj5sMRSjrmBSBeiHym'},
#  {'song_id': '6393yGahSJ9slVdOwSxOVR',
#   'song_name': 'Pink Pony Club',
#   'song_popularity': 88,
#   'song_url': 'https://open.spotify.com/track/6393yGahSJ9slVdOwSxOVR',
#   'song_duration': 258034,
#   'song_added': '2025-02-06T05:13:38Z',
#   'album_id': '0XKconI47eiBP6qPYHsx9f',
#   'artist_id': '7GlBOeep6PqTfFi59PTUUN'},
#  {'song_id': '7d6yK8v8J484SWH5prIQiE',
#   'song_name': 'VeLDÁ',
#   'song_popularity': 93,
#   'song_url': 'https://open.spotify.com/track/7d6yK8v8J484SWH5prIQiE',
#   'song_duration': 235336,
#   'song_added': '2025-01-08T02:14:55Z',
#   'album_id': '5K79FLRUCSysQnVESLcTdb',
#   'artist_id': '4q3ewBCX7sLwd24euuV69X'},
#  {'song_id': '4sTlQPMyoFMPdhAJvErBN3',
#   'song_name': 'PASSO BEM SOLTO - Slowed',
#   'song_popularity': 91,
#   'song_url': 'https://open.spotify.com/track/4sTlQPMyoFMPdhAJvErBN3',
#   'song_duration': 116072,
#   'song_added': '2025-04-02T00:08:16Z',
#   'album_id': '0I7096R74VFP2xnMmp33sY',
#   'artist_id': '5SCDfg1YoEfI5gFtXqEWah'},
#  {'song_id': '0L5gbpFGU06vqSHacOxgka',
#   'song_name': 'TU TU TU',
#   'song_popularity': 85,
#   'song_url': 'https://open.spotify.com/track/0L5gbpFGU06vqSHacOxgka',
#   'song_duration': 151570,
#   'song_added': '2025-04-16T06:16:31Z',
#   'album_id': '34OOEmWpj7OnO5kCfal1MO',
#   'artist_id': '0NlNru2YcUz6RbnpYGQz26'},
#  {'song_id': '7KA4W4McWYRpgf0fWsJZWB',
#   'song_name': 'See You Again (feat. Kali Uchis)',
#   'song_popularity': 93,
#   'song_url': 'https://open.spotify.com/track/7KA4W4McWYRpgf0fWsJZWB',
#   'song_duration': 180386,
#   'song_added': '2025-01-02T15:25:39Z',
#   'album_id': '2nkto6YNI4rUYTLqEwWJ3o',
#   'artist_id': '4V8LLVI7PbaPR0K2TGSxFF'},
#  {'song_id': '3AJwUDP919kvQ9QcozQPxg',
#   'song_name': 'Yellow',
#   'song_popularity': 93,
#   'song_url': 'https://open.spotify.com/track/3AJwUDP919kvQ9QcozQPxg',
#   'song_duration': 266773,
#   'song_added': '2025-01-02T15:25:39Z',
#   'album_id': '6ZG5lRT77aJ3btmArcykra',
#   'artist_id': '4gzpq5DPGxSnKTe4SA8HAU'},
#  {'song_id': '3hpm0fTeSqlhJbnqAgaLZs',
#   'song_name': 'Marlboro Rojo',
#   'song_popularity': 80,
#   'song_url': 'https://open.spotify.com/track/3hpm0fTeSqlhJbnqAgaLZs',
#   'song_duration': 184173,
#   'song_added': '2025-05-13T21:32:21Z',
#   'album_id': '1JpJzuM4uncCfCimVozkmy',
#   'artist_id': '0ys2OFYzWYB5hRDLCsBqxt'},
#  {'song_id': '5Z0UnEtpLDQyYlWwgi8m9C',
#   'song_name': 'Too Sweet',
#   'song_popularity': 22,
#   'song_url': 'https://open.spotify.com/track/5Z0UnEtpLDQyYlWwgi8m9C',
#   'song_duration': 251424,
#   'song_added': '2025-01-02T15:25:39Z',
#   'album_id': '3P4SQqMMgjqfqVxgLwtYRk',
#   'artist_id': '2FXC3k01G6Gw61bmprjgqS'},
#  {'song_id': '2RdEC8Ff83WkX7kDVCHseE',
#   'song_name': 'party 4 u',
#   'song_popularity': 90,
#   'song_url': 'https://open.spotify.com/track/2RdEC8Ff83WkX7kDVCHseE',
#   'song_duration': 296653,
#   'song_added': '2025-04-22T22:33:04Z',
#   'album_id': '3a9qH2VEsSiOZvMrjaS0Nu',
#   'artist_id': '25uiPmTg16RbhZWAqwLBy5'},
#  {'song_id': '1QV6tiMFM6fSOKOGLMHYYg',
#   'song_name': 'Poker Face',
#   'song_popularity': 88,
#   'song_url': 'https://open.spotify.com/track/1QV6tiMFM6fSOKOGLMHYYg',
#   'song_duration': 237200,
#   'song_added': '2025-02-06T06:10:49Z',
#   'album_id': '1qwlxZTNLe1jq3b0iidlue',
#   'artist_id': '1HY2Jd0NmPuamShAr6KMms'},
#  {'song_id': '3be9ACTxtcL6Zm4vJRUiPG',
#   'song_name': 'blue',
#   'song_popularity': 92,
#   'song_url': 'https://open.spotify.com/track/3be9ACTxtcL6Zm4vJRUiPG',
#   'song_duration': 214357,
#   'song_added': '2025-01-02T15:25:39Z',
#   'album_id': '5aelly3dAJd7yZlgUHpLBw',
#   'artist_id': '6zO1dZ40fTZ5hY9NnnRJSk'},
#  {'song_id': '0BxE4FqsDD1Ot4YuBXwAPp',
#   'song_name': '505',
#   'song_popularity': 89,
#   'song_url': 'https://open.spotify.com/track/0BxE4FqsDD1Ot4YuBXwAPp',
#   'song_duration': 253586,
#   'song_added': '2025-01-02T15:25:39Z',
#   'album_id': '1XkGORuUX2QGOEIL4EbJKm',
#   'artist_id': '7Ln80lUS6He07XvHI8qqHH'},
#  {'song_id': '3D24ErT1MMmUfXWotSj2A2',
#   'song_name': 'ME JALO',
#   'song_popularity': 92,
#   'song_url': 'https://open.spotify.com/track/3D24ErT1MMmUfXWotSj2A2',
#   'song_duration': 212002,
#   'song_added': '2025-01-02T15:25:39Z',
#   'album_id': '5utxE1ImIDJFXRHf137hoy',
#   'artist_id': '0ys2OFYzWYB5hRDLCsBqxt'},
#  {'song_id': '7F25roCtYi55JouckaayPC',
#   'song_name': 'Judas',
#   'song_popularity': 87,
#   'song_url': 'https://open.spotify.com/track/7F25roCtYi55JouckaayPC',
#   'song_duration': 249066,
#   'song_added': '2025-04-16T06:19:45Z',
#   'album_id': '6LY3AerY6KNGOPsNPL63Kk',
#   'artist_id': '1HY2Jd0NmPuamShAr6KMms'},
#  {'song_id': '5G2f63n7IPVPPjfNIGih7Q',
#   'song_name': 'Taste',
#   'song_popularity': 92,
#   'song_url': 'https://open.spotify.com/track/5G2f63n7IPVPPjfNIGih7Q',
#   'song_duration': 157279,
#   'song_added': '2025-01-02T15:25:39Z',
#   'album_id': '3iPSVi54hsacKKl1xIR2eH',
#   'artist_id': '74KM79TiuVKeVCqs8QtB0B'},
#  {'song_id': '2HRgqmZQC0MC7GeNuDIXHN',
#   'song_name': 'Seven (feat. Latto) (Explicit Ver.)',
#   'song_popularity': 85,
#   'song_url': 'https://open.spotify.com/track/2HRgqmZQC0MC7GeNuDIXHN',
#   'song_duration': 183550,
#   'song_added': '2025-01-02T15:25:39Z',
#   'album_id': '5pSk3c3wVwnb2arb6ohCPU',
#   'artist_id': '6HaGTQPmzraVmaVxvz6EUc'},
#  {'song_id': '3jS9G4KmuOwuawj3k4Smpc',
#   'song_name': 'Vita Fer',
#   'song_popularity': 64,
#   'song_url': 'https://open.spotify.com/track/3jS9G4KmuOwuawj3k4Smpc',
#   'song_duration': 184743,
#   'song_added': '2025-05-13T21:33:52Z',
#   'album_id': '0L0WsHBFK6x1FdsobtH9Ko',
#   'artist_id': '1ZMJSCQw8DIefcLb1FIpY0'},
#  {'song_id': '1mea3bSkSGXuIRvnydlB5b',
#   'song_name': 'Viva La Vida',
#   'song_popularity': 90,
#   'song_url': 'https://open.spotify.com/track/1mea3bSkSGXuIRvnydlB5b',
#   'song_duration': 242373,
#   'song_added': '2025-01-02T15:25:39Z',
#   'album_id': '1CEODgTmTwLyabvwd7HBty',
#   'artist_id': '4gzpq5DPGxSnKTe4SA8HAU'},
#  {'song_id': '3gZqHdjeKghI5QFjTdOWCU',
#   'song_name': 'Revolving door',
#   'song_popularity': 76,
#   'song_url': 'https://open.spotify.com/track/3gZqHdjeKghI5QFjTdOWCU',
#   'song_duration': 180032,
#   'song_added': '2025-02-25T23:32:36Z',
#   'album_id': '6KaEpgeZQF6ZVVAmSoZUrb',
#   'artist_id': '45dkTj5sMRSjrmBSBeiHym'},
#  {'song_id': '0l0vcZMU7AOeQmUIREoI2U',
#   'song_name': 'Qué Pasaría...',
#   'song_popularity': 91,
#   'song_url': 'https://open.spotify.com/track/0l0vcZMU7AOeQmUIREoI2U',
#   'song_duration': 191018,
#   'song_added': '2025-01-02T15:25:39Z',
#   'album_id': '0aX0UXrHG2ceYIxTQcqJdA',
#   'artist_id': '1mcTU81TzQhprhouKaTkpq'},
#  {'song_id': '2esZG2XFtuoWWA9AfDvSxy',
#   'song_name': 'Gata Only',
#   'song_popularity': 83,
#   'song_url': 'https://open.spotify.com/track/2esZG2XFtuoWWA9AfDvSxy',
#   'song_duration': 222000,
#   'song_added': '2025-01-02T15:25:39Z',
#   'album_id': '6MikZBKCtKfPM4439yzBRz',
#   'artist_id': '7CvTknweLr9feJtRGrpDBy'},
#  {'song_id': '4DnrAI8WyUY6gkOwl8GlPN',
#   'song_name': 'capaz (merengueton)',
#   'song_popularity': 90,
#   'song_url': 'https://open.spotify.com/track/4DnrAI8WyUY6gkOwl8GlPN',
#   'song_duration': 173858,
#   'song_added': '2025-01-02T15:25:39Z',
#   'album_id': '0sWJ3v0FROzcNzyjNYUs6t',
#   'artist_id': '3DeOmVSmpv7WknXoo1OS8p'},
#  {'song_id': '70LcF31zb1H0PyJoS1Sx1r',
#   'song_name': 'Creep',
#   'song_popularity': 91,
#   'song_url': 'https://open.spotify.com/track/70LcF31zb1H0PyJoS1Sx1r',
#   'song_duration': 238640,
#   'song_added': '2025-01-02T15:25:39Z',
#   'album_id': '3gBVdu4a1MMJVMy6vwPEb8',
#   'artist_id': '4Z8W4fKeB5YxbusRsdQVPb'},
#  {'song_id': '3BntzKsnLf2pc0dsvE3Zav',
#   'song_name': 'Bad Dreams',
#   'song_popularity': 89,
#   'song_url': 'https://open.spotify.com/track/3BntzKsnLf2pc0dsvE3Zav',
#   'song_duration': 184577,
#   'song_added': '2025-02-19T18:18:06Z',
#   'album_id': '6kvSdLjli85tMwW4jlCN0o',
#   'artist_id': '33qOK5uJ8AR2xuQQAhHump'},
#  {'song_id': '4N1dogCaVWnGyFdPjdqNWF',
#   'song_name': 'COMO CAPO',
#   'song_popularity': 86,
#   'song_url': 'https://open.spotify.com/track/4N1dogCaVWnGyFdPjdqNWF',
#   'song_duration': 165482,
#   'song_added': '2025-04-09T00:04:42Z',
#   'album_id': '34OOEmWpj7OnO5kCfal1MO',
#   'artist_id': '0NlNru2YcUz6RbnpYGQz26'},
#  {'song_id': '221eHga9f9Ne4f8D7WVgPT',
#   'song_name': 'Mystical Magical',
#   'song_popularity': 88,
#   'song_url': 'https://open.spotify.com/track/221eHga9f9Ne4f8D7WVgPT',
#   'song_duration': 165746,
#   'song_added': '2025-04-29T21:48:34Z',
#   'album_id': '7y5UZkCSxTUo47pxeTWbXK',
#   'artist_id': '22wbnEMDvgVIAGdFeek6ET'},
#  {'song_id': '5tlb0AxuzsMWL2GtEppXGX',
#   'song_name': 'Multo',
#   'song_popularity': 86,
#   'song_url': 'https://open.spotify.com/track/5tlb0AxuzsMWL2GtEppXGX',
#   'song_duration': 237692,
#   'song_added': '2025-04-08T23:56:20Z',
#   'album_id': '2WOyuTsNHF90SryrS3kmIN',
#   'artist_id': '61nn6nOoLWjVC1ER2qFAvN'},
#  {'song_id': '2FAZskT9yRjp2Oow9szJD8',
#   'song_name': 'The Days - NOTION Remix',
#   'song_popularity': 92,
#   'song_url': 'https://open.spotify.com/track/2FAZskT9yRjp2Oow9szJD8',
#   'song_duration': 233229,
#   'song_added': '2025-01-14T17:19:42Z',
#   'album_id': '15gT6ikjvzrlIxQ5eTpqLJ',
#   'artist_id': '5bQ3wFgekuIMIcWJuxkqLK'},
#  {'song_id': '7MXVkk9YMctZqd1Srtv4MB',
#   'song_name': 'Starboy',
#   'song_popularity': 91,
#   'song_url': 'https://open.spotify.com/track/7MXVkk9YMctZqd1Srtv4MB',
#   'song_duration': 230453,
#   'song_added': '2025-01-02T15:25:39Z',
#   'album_id': '2ODvWsOgouMbaA5xf0RkJe',
#   'artist_id': '1Xyo4u8uXC1ZmMpatF05PJ'},
#  {'song_id': '5fZJQrFKWQLb7FpJXZ1g7K',
#   'song_name': 'A Bar Song (Tipsy)',
#   'song_popularity': 86,
#   'song_url': 'https://open.spotify.com/track/5fZJQrFKWQLb7FpJXZ1g7K',
#   'song_duration': 171291,
#   'song_added': '2025-01-02T15:25:39Z',
#   'album_id': '0DLvFVIfwt3OHdK9kGeEM3',
#   'artist_id': '3y2cIKLjiOlp1Np37WiUdH'},
#  {'song_id': '51ZQ1vr10ffzbwIjDCwqm4',
#   'song_name': "we can't be friends (wait for your love)",
#   'song_popularity': 89,
#   'song_url': 'https://open.spotify.com/track/51ZQ1vr10ffzbwIjDCwqm4',
#   'song_duration': 228639,
#   'song_added': '2025-01-02T15:25:39Z',
#   'album_id': '5EYKrEDnKhhcNxGedaRQeK',
#   'artist_id': '66CXWjxzNUsdJxJ2JdwvnR'},
#  {'song_id': '3Vr3zh0r7ALn8VLqCiRR10',
#   'song_name': 'Stargazing',
#   'song_popularity': 90,
#   'song_url': 'https://open.spotify.com/track/3Vr3zh0r7ALn8VLqCiRR10',
#   'song_duration': 172533,
#   'song_added': '2025-05-06T23:23:29Z',
#   'album_id': '3VNxRarx9HUI5w7DHv0TBj',
#   'artist_id': '3bO19AOone0ubCsfDXDtYt'},
#  {'song_id': '0aB0v4027ukVziUGwVGYpG',
#   'song_name': 'tv off (feat. lefty gunplay)',
#   'song_popularity': 93,
#   'song_url': 'https://open.spotify.com/track/0aB0v4027ukVziUGwVGYpG',
#   'song_duration': 220690,
#   'song_added': '2025-01-02T15:25:39Z',
#   'album_id': '0hvT3yIEysuuvkK73vgdcW',
#   'artist_id': '2YZyLoL8N0Wb9xBt1NhZWg'},
#  {'song_id': '2OxvanM5m1Na9OVlXyXmUp',
#   'song_name': 'Lesung Pipi',
#   'song_popularity': 86,
#   'song_url': 'https://open.spotify.com/track/2OxvanM5m1Na9OVlXyXmUp',
#   'song_duration': 225153,
#   'song_added': '2025-04-16T06:05:22Z',
#   'album_id': '5HKEezqSNuJSD5Nbrs9bhG',
#   'artist_id': '5LcNPa8f8bRmZqELgoRFkN'},
#  {'song_id': '0auX6W6oLjO9cHmx4UTaNj',
#   'song_name': 'Feel It',
#   'song_popularity': 78,
#   'song_url': 'https://open.spotify.com/track/0auX6W6oLjO9cHmx4UTaNj',
#   'song_duration': 157974,
#   'song_added': '2025-05-06T23:30:16Z',
#   'album_id': '00xSzSrckgOgVAqZUIcrxf',
#   'artist_id': '5y8tKLUfMvliMe8IKamR32'},
#  {'song_id': '0GRc3eGTg8HBdWLRGYgqIc',
#   'song_name': 'Azizam',
#   'song_popularity': 91,
#   'song_url': 'https://open.spotify.com/track/0GRc3eGTg8HBdWLRGYgqIc',
#   'song_duration': 162029,
#   'song_added': '2025-04-08T23:56:36Z',
#   'album_id': '37HwcDtLqY2WXN7NArODvI',
#   'artist_id': '6eUKZXaKkcviH0Ku9w2n3V'},
#  {'song_id': '3x3K1RP3Zfi2qeMR8kyrNO',
#   'song_name': "Sorry I'm Here For Someone Else",
#   'song_popularity': 91,
#   'song_url': 'https://open.spotify.com/track/3x3K1RP3Zfi2qeMR8kyrNO',
#   'song_duration': 156582,
#   'song_added': '2025-04-09T00:04:54Z',
#   'album_id': '38PKSUSFXnO4mbUhLC4ELZ',
#   'artist_id': '22wbnEMDvgVIAGdFeek6ET'},
#  {'song_id': '60a0Rd6pjrkxjPbaKzXjfq',
#   'song_name': 'In the End',
#   'song_popularity': 90,
#   'song_url': 'https://open.spotify.com/track/60a0Rd6pjrkxjPbaKzXjfq',
#   'song_duration': 216880,
#   'song_added': '2025-03-12T00:03:06Z',
#   'album_id': '6hPkbAV3ZXpGZBGUvL6jVM',
#   'artist_id': '6XyY86QOPPrYVGvF9ch6wz'},
#  {'song_id': '6jbYpRPTEFl1HFKHk1IC0m',
#   'song_name': 'Like Him (feat. Lola Young)',
#   'song_popularity': 91,
#   'song_url': 'https://open.spotify.com/track/6jbYpRPTEFl1HFKHk1IC0m',
#   'song_duration': 278014,
#   'song_added': '2025-01-02T15:25:39Z',
#   'album_id': '0U28P0QVB1QRxpqp5IHOlH',
#   'artist_id': '4V8LLVI7PbaPR0K2TGSxFF'},
#  {'song_id': '2VxeLyX666F8uXCJ0dZF8B',
#   'song_name': 'Shallow',
#   'song_popularity': 87,
#   'song_url': 'https://open.spotify.com/track/2VxeLyX666F8uXCJ0dZF8B',
#   'song_duration': 215733,
#   'song_added': '2025-02-06T06:07:29Z',
#   'album_id': '4sLtOBOzn4s3GDUv3c5oJD',
#   'artist_id': '1HY2Jd0NmPuamShAr6KMms'},
#  {'song_id': '1HNkqx9Ahdgi1Ixy2xkKkL',
#   'song_name': 'Photograph',
#   'song_popularity': 89,
#   'song_url': 'https://open.spotify.com/track/1HNkqx9Ahdgi1Ixy2xkKkL',
#   'song_duration': 258986,
#   'song_added': '2025-02-19T18:33:38Z',
#   'album_id': '1xn54DMo2qIqBuMqHtUsFd',
#   'artist_id': '6eUKZXaKkcviH0Ku9w2n3V'},
#  {'song_id': '6uroNiDEDd0xFLiri0aQNk',
#   'song_name': 'Triple Lavada',
#   'song_popularity': 89,
#   'song_url': 'https://open.spotify.com/track/6uroNiDEDd0xFLiri0aQNk',
#   'song_duration': 165790,
#   'song_added': '2025-04-16T06:02:57Z',
#   'album_id': '1rsjecCzLbJS7YVALG6I7P',
#   'artist_id': '6VcsqZOR5AtEOGeAtmutCZ'},
#  {'song_id': '0DMJz677XfXiiruhIELu2e',
#   'song_name': 'VITAMINA',
#   'song_popularity': 92,
#   'song_url': 'https://open.spotify.com/track/0DMJz677XfXiiruhIELu2e',
#   'song_duration': 208743,
#   'song_added': '2025-03-11T23:46:28Z',
#   'album_id': '6jf5qinEHzsxyBQgvrW916',
#   'artist_id': '3Y9A8EQQtWU8RStiTlzErv'},
#  {'song_id': '0fea68AdmYNygeTGI4RC18',
#   'song_name': 'LA CANCIÓN',
#   'song_popularity': 89,
#   'song_url': 'https://open.spotify.com/track/0fea68AdmYNygeTGI4RC18',
#   'song_duration': 242573,
#   'song_added': '2025-05-06T23:43:39Z',
#   'album_id': '6ylFfzx32ICw4L1A7YWNLN',
#   'artist_id': '1vyhD5VmyZ7KMfW5gqLgo5'},
#  {'song_id': '3qhlB30KknSejmIvZZLjOD',
#   'song_name': 'End of Beginning',
#   'song_popularity': 91,
#   'song_url': 'https://open.spotify.com/track/3qhlB30KknSejmIvZZLjOD',
#   'song_duration': 159245,
#   'song_added': '2025-01-02T15:25:39Z',
#   'album_id': '4JDXBZdRPId4devseaAOKH',
#   'artist_id': '5p9HO3XC5P3BLxJs5Mtrhm'},
#  {'song_id': '4eLDmhsJW3JoZTXCAozHor',
#   'song_name': 'Loco',
#   'song_popularity': 87,
#   'song_url': 'https://open.spotify.com/track/4eLDmhsJW3JoZTXCAozHor',
#   'song_duration': 186521,
#   'song_added': '2025-02-19T18:12:21Z',
#   'album_id': '338NDGMHtB4t5mp8RhMnh3',
#   'artist_id': '6pV5zH2LzjOUHaAvENdMMa'},
#  {'song_id': '7EW7Yivb93qKAtp5qEm5of',
#   'song_name': 'Dark Thoughts',
#   'song_popularity': 92,
#   'song_url': 'https://open.spotify.com/track/7EW7Yivb93qKAtp5qEm5of',
#   'song_duration': 136991,
#   'song_added': '2025-03-18T20:19:07Z',
#   'album_id': '7BnNV4WZAG7rFqUeMHRdUP',
#   'artist_id': '4Ga1P7PMIsmqEZqhYZQgDo'},
#  {'song_id': '3AVrVz5rK8Hrqo9YGiVGN5',
#   'song_name': 'Apocalypse',
#   'song_popularity': 7,
#   'song_url': 'https://open.spotify.com/track/3AVrVz5rK8Hrqo9YGiVGN5',
#   'song_duration': 290146,
#   'song_added': '2025-01-02T15:25:39Z',
#   'album_id': '5bP82ZIls6rzhpf5Qu6AzC',
#   'artist_id': '1QAJqy2dA3ihHBFIHRphZj'},
#  {'song_id': '3JvKfv6T31zO0ini8iNItO',
#   'song_name': 'Another Love',
#   'song_popularity': 89,
#   'song_url': 'https://open.spotify.com/track/3JvKfv6T31zO0ini8iNItO',
#   'song_duration': 244360,
#   'song_added': '2025-01-02T15:25:39Z',
#   'album_id': '0Gf1yE895FKK4YWVRuAeg8',
#   'artist_id': '2txHhyCwHjUEpJjWrEyqyX'},
#  {'song_id': '0QCIpQV3twfqo9kh0t8Zza',
#   'song_name': 'Shake It To The Max (FLY) - Remix',
#   'song_popularity': 86,
#   'song_url': 'https://open.spotify.com/track/0QCIpQV3twfqo9kh0t8Zza',
#   'song_duration': 178775,
#   'song_added': '2025-05-13T21:32:54Z',
#   'album_id': '7jhHpyhKorvt65mYvuhlBs',
#   'artist_id': '2hVWBpjLW4Q7fboYz2pVYK'},
#  {'song_id': '2tHwzyyOLoWSFqYNjeVMzj',
#   'song_name': 'Please Please Please',
#   'song_popularity': 88,
#   'song_url': 'https://open.spotify.com/track/2tHwzyyOLoWSFqYNjeVMzj',
#   'song_duration': 186365,
#   'song_added': '2025-01-02T15:25:39Z',
#   'album_id': '3iPSVi54hsacKKl1xIR2eH',
#   'artist_id': '74KM79TiuVKeVCqs8QtB0B'},
#  {'song_id': '5IZXB5IKAD2qlvTPJYDCFB',
#   'song_name': 'I Had Some Help (Feat. Morgan Wallen)',
#   'song_popularity': 87,
#   'song_url': 'https://open.spotify.com/track/5IZXB5IKAD2qlvTPJYDCFB',
#   'song_duration': 178205,
#   'song_added': '2025-01-02T15:25:39Z',
#   'album_id': '4BbsHmXEghoPPevQjPnHXx',
#   'artist_id': '246dkjvS1zLTtiykXe5h60'},
#  {'song_id': '4MUrUT38U98olfnyzMBCzm',
#   'song_name': 'KLOuFRENS',
#   'song_popularity': 90,
#   'song_url': 'https://open.spotify.com/track/4MUrUT38U98olfnyzMBCzm',
#   'song_duration': 199114,
#   'song_added': '2025-01-08T02:14:55Z',
#   'album_id': '5K79FLRUCSysQnVESLcTdb',
#   'artist_id': '4q3ewBCX7sLwd24euuV69X'},
#  {'song_id': '2tpWsVSb9UEmDRxAl1zhX1',
#   'song_name': 'Counting Stars',
#   'song_popularity': 90,
#   'song_url': 'https://open.spotify.com/track/2tpWsVSb9UEmDRxAl1zhX1',
#   'song_duration': 257265,
#   'song_added': '2025-01-02T15:25:39Z',
#   'album_id': '20lOt6G8MHv8ZO7ViOmiP7',
#   'artist_id': '5Pwc4xIPtQLFEnJriah9YJ'}]

# %%
# convert to a dataframe
album_df = pd.DataFrame(album_list)
album_df = album_df.drop_duplicates(subset=['album_id'])
album_df.head()
# Out:
#                  album_id                          album_name  \
# 0  1eCGY9WJpYgtaFh1Lk2KNo  You'll Be Alright, Kid (Chapter 1)
# 1  2MHUaRi9OCyTN02SoyRRBJ                              MAYHEM
# 2  7aJuG4TFXa2hmE4z1yxc3n                HIT ME HARD AND SOFT
# 3  7kFyd5oyJdVX2pIi6P4iHE                               rosie
# 4  5K79FLRUCSysQnVESLcTdb                DeBÍ TiRAR MáS FOToS
#
#   album_release_date  album_total_tracks  \
# 0         2024-09-26                  11
# 1         2025-03-07                  14
# 2         2024-05-17                  10
# 3         2024-12-06                  12
# 4         2025-01-05                  17
#
#                                            album_url
# 0  https://open.spotify.com/album/1eCGY9WJpYgtaFh...
# 1  https://open.spotify.com/album/2MHUaRi9OCyTN02...
# 2  https://open.spotify.com/album/7aJuG4TFXa2hmE4...
# 3  https://open.spotify.com/album/7kFyd5oyJdVX2pI...
# 4  https://open.spotify.com/album/5K79FLRUCSysQnV...

# %%
artist_df = pd.DataFrame(artist_list)
artist_df = artist_df.drop_duplicates(subset=['artist_id'])
artist_df.head()
# Out:
#                 artist_id    artist_name  \
# 0  0fTSzq9jAh4c36UVb4V7CB    Alex Warren
# 1  1HY2Jd0NmPuamShAr6KMms      Lady Gaga
# 2  0du5cEVh5yTK9QJze8zA0C     Bruno Mars
# 3  6qqNVTkY8uBg9cP3Jd7DAH  Billie Eilish
# 4  3eVa5w3URK5duf6eyVDbu9           ROSÉ
#
#                                  artist_external_url
# 0  https://open.spotify.com/artist/0fTSzq9jAh4c36...
# 1  https://open.spotify.com/artist/1HY2Jd0NmPuamS...
# 2  https://open.spotify.com/artist/0du5cEVh5yTK9Q...
# 3  https://open.spotify.com/artist/6qqNVTkY8uBg9c...
# 4  https://open.spotify.com/artist/3eVa5w3URK5duf...

# %%
song_df = pd.DataFrame(song_list)
song_df.head()
# Out:
#                   song_id           song_name  song_popularity  \
# 0  2RkZ5LkEzeHGRsmDqKwmaJ            Ordinary               92
# 1  7so0lgd0zP2Sbgs2d7a1SZ    Die With A Smile               91
# 2  6dOtVTDdiauQNBQEDOtlAB  BIRDS OF A FEATHER              100
# 3  4wJ5Qq0jBN4ajy7ouZIV1c                APT.               91
# 4  3sK8wGT43QFpWrvNQsrQya                DtMF               97
#
#                                             song_url  song_duration  \
# 0  https://open.spotify.com/track/2RkZ5LkEzeHGRsm...         186964
# 1  https://open.spotify.com/track/7so0lgd0zP2Sbgs...         251667
# 2  https://open.spotify.com/track/6dOtVTDdiauQNBQ...         210373
# 3  https://open.spotify.com/track/4wJ5Qq0jBN4ajy7...         169917
# 4  https://open.spotify.com/track/3sK8wGT43QFpWrv...         237117
#
#              song_added                album_id               artist_id
# 0  2025-04-01T23:38:28Z  1eCGY9WJpYgtaFh1Lk2KNo  0fTSzq9jAh4c36UVb4V7CB
# 1  2025-03-11T23:15:56Z  2MHUaRi9OCyTN02SoyRRBJ  1HY2Jd0NmPuamShAr6KMms
# 2  2025-01-02T15:25:39Z  7aJuG4TFXa2hmE4z1yxc3n  6qqNVTkY8uBg9cP3Jd7DAH
# 3  2025-01-02T15:25:39Z  7kFyd5oyJdVX2pIi6P4iHE  3eVa5w3URK5duf6eyVDbu9
# 4  2025-01-08T02:14:55Z  5K79FLRUCSysQnVESLcTdb  4q3ewBCX7sLwd24euuV69X

# %%
# converting to proper datetime
album_df['album_release_date'] = pd.to_datetime(album_df['album_release_date'], errors='coerce')
album_df.info()
album_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 85 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   album_id            85 non-null     object
#  1   album_name          85 non-null     object
#  2   album_release_date  84 non-null     datetime64[ns]
#  3   album_total_tracks  85 non-null     int64
#  4   album_url           85 non-null     object
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 4.0+ KB
#                  album_id                          album_name  \
# 0  1eCGY9WJpYgtaFh1Lk2KNo  You'll Be Alright, Kid (Chapter 1)
# 1  2MHUaRi9OCyTN02SoyRRBJ                              MAYHEM
# 2  7aJuG4TFXa2hmE4z1yxc3n                HIT ME HARD AND SOFT
# 3  7kFyd5oyJdVX2pIi6P4iHE                               rosie
# 4  5K79FLRUCSysQnVESLcTdb                DeBÍ TiRAR MáS FOToS
#
#   album_release_date  album_total_tracks  \
# 0         2024-09-26                  11
# 1         2025-03-07                  14
# 2         2024-05-17                  10
# 3         2024-12-06                  12
# 4         2025-01-05                  17
#
#                                            album_url
# 0  https://open.spotify.com/album/1eCGY9WJpYgtaFh...
# 1  https://open.spotify.com/album/2MHUaRi9OCyTN02...
# 2  https://open.spotify.com/album/7aJuG4TFXa2hmE4...
# 3  https://open.spotify.com/album/7kFyd5oyJdVX2pI...
# 4  https://open.spotify.com/album/5K79FLRUCSysQnV...

# %%
song_df['song_added'] = pd.to_datetime(song_df['song_added']) 
song_df.info()
song_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   song_id          100 non-null    object
#  1   song_name        100 non-null    object
#  2   song_popularity  100 non-null    int64
#  3   song_url         100 non-null    object
#  4   song_duration    100 non-null    int64
#  5   song_added       100 non-null    datetime64[ns, UTC]
#  6   album_id         100 non-null    object
#  7   artist_id        100 non-null    object
# dtypes: datetime64[ns, UTC](1), int64(2), object(5)
# memory usage: 6.4+ KB
#                   song_id           song_name  song_popularity  \
# 0  2RkZ5LkEzeHGRsmDqKwmaJ            Ordinary               92
# 1  7so0lgd0zP2Sbgs2d7a1SZ    Die With A Smile               91
# 2  6dOtVTDdiauQNBQEDOtlAB  BIRDS OF A FEATHER              100
# 3  4wJ5Qq0jBN4ajy7ouZIV1c                APT.               91
# 4  3sK8wGT43QFpWrvNQsrQya                DtMF               97
#
#                                             song_url  song_duration  \
# 0  https://open.spotify.com/track/2RkZ5LkEzeHGRsm...         186964
# 1  https://open.spotify.com/track/7so0lgd0zP2Sbgs...         251667
# 2  https://open.spotify.com/track/6dOtVTDdiauQNBQ...         210373
# 3  https://open.spotify.com/track/4wJ5Qq0jBN4ajy7...         169917
# 4  https://open.spotify.com/track/3sK8wGT43QFpWrv...         237117
#
#                  song_added                album_id               artist_id
# 0 2025-04-01 23:38:28+00:00  1eCGY9WJpYgtaFh1Lk2KNo  0fTSzq9jAh4c36UVb4V7CB
# 1 2025-03-11 23:15:56+00:00  2MHUaRi9OCyTN02SoyRRBJ  1HY2Jd0NmPuamShAr6KMms
# 2 2025-01-02 15:25:39+00:00  7aJuG4TFXa2hmE4z1yxc3n  6qqNVTkY8uBg9cP3Jd7DAH
# 3 2025-01-02 15:25:39+00:00  7kFyd5oyJdVX2pIi6P4iHE  3eVa5w3URK5duf6eyVDbu9
# 4 2025-01-08 02:14:55+00:00  5K79FLRUCSysQnVESLcTdb  4q3ewBCX7sLwd24euuV69X
